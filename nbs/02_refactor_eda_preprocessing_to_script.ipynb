# %% [markdown]
# # Exploratory Data Analysis of Epicurious Scrape in a JSON file
#
# This is an idealized workflow for Aaron Chen in looking at data science problems. It likely isn't the best path, nor has he rigidly applied or stuck to this ideal, but he wishes that he worked this way more frequently.
#
# ## Purpose: Work through some exploratory data analysis of the Epicurious scrape on stream. Try to write some functions to help process the data.
#
# ### Author: Aaron Chen

# %% [markdown]
# ---

# %% [markdown]
# ### If needed, run shell commands here

# %%
#!python -m spacy download en_core_web_sm

# %% [markdown]
# ---

# %% [markdown]
# ## External Resources
#
# List out references or documentation that has helped you with this notebook
#
# ### Code
# Regex Checker: https://regex101.com/
#
# #### Scikit-learn
# 1. https://scikit-learn.org/stable/modules/decomposition.html#latent-dirichlet-allocation-lda
#
#
# ### Data
#
# For this notebook, the data is stored in the repo base folder/data/raw
#
# ### Process
#
# Are there steps or tutorials you are following? Those are things I try to list in Process

# %% [markdown]
# ---

# %% [markdown]
# ## Import necessary libraries

# %%
# | hide
import project_path
from datetime import datetime
import numpy as np
import pandas as pd
from sklearn.base import TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

import spacy
import en_core_web_sm
from spacy.lang.en.stop_words import STOP_WORDS
from tqdm import tqdm
from typing import Dict
import unicodedata

# import local scripts
import src.dataframe_preprocessor as dfpp

# %% [markdown]
# ---

# %% [markdown]
# ## Define helper functions
#
# My workflow is to try things with code cells, then when the code cells get messy and repetitive, to convert into helper functions that can be called.
#
# When the helper functions are getting used a lot, it is usually better to convert them to scripts or classes that can be called/instantiated

# %%
# | export
def preprocess_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    """This function takes in a pandas DataFrame from pd.read_json and performs some preprocessing by unpacking the nested dictionaries and creating new columns with the simplified structures. It will then drop the original columns that would no longer be needed.

    Args:
        pd.DataFrame

    Returns:
        pd.DataFrame
    """

    def null_filler(to_check: Dict[str, str], key_target: str) -> str:
        """This function takes in a dictionary that is currently fed in with a lambda function and then performs column specific preprocessing.

        Args:
            to_check: dict
            key_target: str

        Returns:
            str
        """

        # Only look in the following keys, if the input isn't one of these, it should be recognized as an improper key
        valid_keys = ["name", "filename", "credit"]

        # This dictionary converts the input keys into substrings that can be used in f-strings to fill in missing values in the record
        translation_keys = {
            "name": "Cuisine",
            "filename": "Photo",
            "credit": "Photo Credit",
        }

        if key_target not in valid_keys:
            # this logic makes sure we are only looking at valid keys
            return (
                "Improper key target: can only pick from 'name', 'filename', 'credit'."
            )

        else:
            if pd.isna(to_check):
                # this logic checks to see if the dictionary exists at all. if so, return Missing
                return f"Missing {translation_keys[key_target]}"
            else:
                if key_target == "name" and (to_check["category"] != "cuisine"):
                    # This logic checks for the cuisine, if the cuisine is not there (and instead has 'ingredient', 'type', 'item', 'equipment', 'meal'), mark as missing
                    return f"Missing {translation_keys[key_target]}"
                else:
                    # Otherwise, there should be no issue with returning
                    return to_check[key_target]

    # Dive into the tag column and extract the cuisine label. Put into new column or fills with "missing data"
    df["cuisine_name"] = df["tag"].apply(
        lambda x: null_filler(to_check=x, key_target="name")
    )
    # df["cuisine_name"] = df["tag"].apply(lambda x: x['name'] if not pd.isna(x) and x['category'] == 'cuisine' else 'Cuisine Missing')

    # this lambda function goes into the photo data column and extracts just the filename from the dictionary
    df["photo_filename"] = df["photoData"].apply(
        lambda x: null_filler(to_check=x, key_target="filename")
    )
    # df["photo_filename"] = df['photoData'].apply(lambda x: x['filename'] if not pd.isna(x) else 'Missing photo')

    # This lambda function goes into the photo data column and extracts just the photo credit from the dictionary
    df["photo_credit"] = df["photoData"].apply(
        lambda x: null_filler(to_check=x, key_target="credit")
    )
    # df["photo_credit"] = df['photoData'].apply(lambda x: x['credit'] if not pd.isna(x) else 'Missing credit')

    # for the above, maybe they can be refactored to one function where the arguments are a column name, dictionary key name, the substring return

    # this lambda funciton goes into the author column and extract the author name or fills iwth "missing data"
    df["author_name"] = df["author"].apply(
        lambda x: x[0]["name"] if x else "Missing Author Name"
    )

    # This function takes in the given pubDate column and creates a new column with the pubDate values converted to datetime objects
    df["date_published"] = pd.to_datetime(df["pubDate"], infer_datetime_format=True)

    # drop some original columns to clean up the dataframe
    df.drop(
        labels=["tag", "photoData", "author", "type", "dateCrawled", "pubDate"],
        axis=1,
        inplace=True,
    )

    return df

# %% [markdown]
# ---

# %% [markdown]
# ## Define global variables
#
# **Remember to refactor these out, not ideal**

# %%
# | hide
data_path = "../data/recipes-en-201706/epicurious-recipes_m2.json"

# %% [markdown]
# ---

# %% [markdown]
# ## Running Commentary
#
# 1. I used numbered lists to keep track of things I noticed
#
# ### To Do
#
# 1. Try to determine consistency of nested data structures
#    1. Is the photoData or number of things inside photoData the same from record to record
#    2. What about for tag?
#
# Data wasn't fully consistent but logic in helper function helped handle nulls
#
# 2. How to handle nulls?
#    1. Author      Filled in with "Missing Author"
#    2. Tag         Filled in with "Missing Cuisine"
# 3. ~~Convert pubDate to actual timestamp~~
# 4. ~~Convert ScrapeDate to actual timestamp~~
#    1. This was ignored as the datestamp was not useful (generally within minutes of the origin of UNIX time)
#
# **5. Append new columns for relevant nested structures and unfold them**
#
# 6. Determine actual types of `ingredients` and `prepSteps`
# 7. Continue working through test example of single recipe to feed into spaCy and then sklearn.feature_extraction.text stack
# 8. Will need to remove numbers, punctuation

# %% [markdown]
# ---

# %% [markdown]
# ## Importing and viewing the data as a dataframe
#
# Continuing from previous notebook
#
# Based on the timestamps, it seems like we can drop the crawled/scraped column because the values don't really make sense and would not help
#
# To Do:
# - Refactor datetime processing into functions
# - Consider deploying as a pd.pipe()

# %%
epic_dataframe = pd.read_json(path_or_buf=data_path)
preprocess_dataframe(epic_dataframe)
epic_dataframe.head(10)
# Out:
#                          id  \
# 0  54a2b6b019925f464b373351
# 1  54a408a019925f464b3733bc
# 2  54a408a26529d92b2c003631
# 3  54a408a66529d92b2c003638
# 4  54a408a719925f464b3733cc
# 5  54a408a919925f464b3733d3
# 6  54a408aa19925f464b3733d6
# 7  54a408ab19925f464b3733da
# 8  54a408ac19925f464b3733de
# 9  54a408ac6529d92b2c003653
#
#                                                  dek  \
# 0  How does fried chicken achieve No. 1 status? B...
# 1                                Spinaci all'Ebraica
# 2  This majestic, moist, and richly spiced honey ...
# 3  The idea for this sandwich came to me when my ...
# 4  In 1930, Simon Agranat, the chief justice of t...
# 5  Although Nelly Custis omitted sugar in her rec...
# 6  Editor's note: This recipe is adapted with per...
# 7  Editor's note: This recipe is reprinted with p...
# 8  Editor's note: This recipe is reprinted with p...
# 9  Editor's note: This recipe is reprinted with p...
#
#                                      hed  \
# 0            Pickle-Brined Fried Chicken
# 1                   Spinach Jewish Style
# 2                  New Year’s Honey Cake
# 3  The B.L.A.Bagel with Lox and Avocado
# 4        Shakshuka a la Doktor Shakshuka
# 5                          Rice Pancakes
# 6                        Jack-O'-Lantern
# 7                  Seven-Minute Frosting
# 8                  Creamy White Frosting
# 9                         Host of Ghosts
#
#                                                  url  aggregateRating  \
# 0  /recipes/food/views/pickle-brined-fried-chicke...             3.11
# 1    /recipes/food/views/spinach-jewish-style-350152             3.22
# 2  /recipes/food/views/majestic-and-moist-new-yea...             3.62
# 3  /recipes/food/views/the-b-l-a-bagel-with-lox-a...             4.00
# 4  /recipes/food/views/shakshuka-a-la-doktor-shak...             2.71
# 5           /recipes/food/views/rice-pancakes-394729             0.00
# 6          /recipes/food/views/jack-o-lantern-350068             1.00
# 7   /recipes/food/views/seven-minute-frosting-350069             3.53
# 8   /recipes/food/views/creamy-white-frosting-350079             2.00
# 9          /recipes/food/views/host-of-ghosts-350067             3.17
#
#                                          ingredients  \
# 0  [1 tablespoons yellow mustard seeds, 1 tablesp...
# 1  [3 pounds small-leaved bulk spinach, Salt, 1/2...
# 2  [3 1/2 cups all-purpose flour, 1 tablespoon ba...
# 3  [1 small ripe avocado, preferably Hass (see No...
# 4  [2 pounds fresh tomatoes, unpeeled and cut in ...
# 5  [1 1/2 cups cooked rice, 2 cups heavy cream, 2...
# 6  [2 tablespoons shortening, 2 tablespoons flour...
# 7  [1 1/2 cups sugar, 1/3 cup cold water, 2 egg w...
# 8  [1 cup vegetable shortening, 1 1/2 teaspoons v...
# 9  [One purchased 9-inch angel food cake, 2 recip...
#
#                                            prepSteps  reviewsCount  \
# 0  [Toast mustard and coriander seeds in a dry me...             7
# 1  [Remove the stems and roots from the spinach. ...             5
# 2  [I like this cake best baked in a 9-inch angel...           105
# 3  [A short time before serving, mash avocado and...             7
# 4  [1. Place the tomatoes, garlic, salt, paprika,...             7
# 5  [1. Combine the rice, cream, and butter. Add t...             0
# 6  [1. Preheat the oven to 350°F. Lightly grease ...             1
# 7  [1. Combine the sugar, water, egg whites, and ...             8
# 8  [1. With a mixer on medium speed, beat togethe...             5
# 9  [1. Place the cake on the cake plate. Reserve ...            12
#
#    willMakeAgainPct     cuisine_name                       photo_filename  \
# 0               100  Missing Cuisine       51247610_fried-chicken_1x1.jpg
# 1                80          Italian  EP_12162015_placeholders_rustic.jpg
# 2                88           Jewish          EP_09022015_honeycake-2.jpg
# 3               100           Jewish  EP_12162015_placeholders_casual.jpg
# 4                83           Jewish  EP_12162015_placeholders_formal.jpg
# 5                 0  Missing Cuisine  EP_12162015_placeholders_formal.jpg
# 6                 0  Missing Cuisine                           350068.jpg
# 7                75  Missing Cuisine  EP_12162015_placeholders_bright.jpg
# 8                 0  Missing Cuisine  EP_12162015_placeholders_casual.jpg
# 9               100  Missing Cuisine                           350067.jpg
#
#                                         photo_credit          author_name  \
# 0                Michael Graydon and Nikole Herriott  Missing Author Name
# 1  Photo by Chelsea Kyle, Prop Styling by Anna St...   Edda Servi Machlin
# 2  Photo by Chelsea Kyle, Food Styling by Anna St...        Marcy Goldman
# 3  Photo by Chelsea Kyle, Prop Styling by Rhoda B...            Faye Levy
# 4  Photo by Chelsea Kyle, Prop Styling by Rhoda B...          Joan Nathan
# 5  Photo by Chelsea Kyle, Prop Styling by Rhoda B...    Stephen A. McLeod
# 6                             Jennifer Newberry Mead         Matthew Mead
# 7  Photo by Chelsea Kyle, Prop Styling by Anna St...         Matthew Mead
# 8  Photo by Chelsea Kyle, Prop Styling by Rhoda B...         Matthew Mead
# 9                             Jennifer Newberry Mead         Matthew Mead
#
#              date_published
# 0 2014-08-19 04:00:00+00:00
# 1 2008-09-09 04:00:00+00:00
# 2 2008-09-10 04:00:00+00:00
# 3 2008-09-08 04:00:00+00:00
# 4 2008-09-09 04:00:00+00:00
# 5 2012-02-17 04:00:00+00:00
# 6 2008-09-09 04:00:00+00:00
# 7 2008-09-09 04:00:00+00:00
# 8 2008-09-09 04:00:00+00:00
# 9 2008-09-09 04:00:00+00:00

# %%
epic_dataframe.describe()
# Out:
#        aggregateRating  reviewsCount  willMakeAgainPct
# count     34756.000000  34756.000000      34756.000000
# mean          2.937041     19.467257         75.435579
# std           1.079268     36.121799         31.064887
# min           0.000000      0.000000          0.000000
# 25%           2.860000      3.000000         70.000000
# 50%           3.270000      9.000000         87.000000
# 75%           3.580000     22.000000         98.000000
# max           4.000000   1586.000000        100.000000

# %%
epic_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34756 entries, 0 to 34755
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                34756 non-null  object
#  1   dek               34756 non-null  object
#  2   hed               34756 non-null  object
#  3   url               34756 non-null  object
#  4   aggregateRating   34756 non-null  float64
#  5   ingredients       34656 non-null  object
#  6   prepSteps         34756 non-null  object
#  7   reviewsCount      34756 non-null  int64
#  8   willMakeAgainPct  34756 non-null  int64
#  9   cuisine_name      34756 non-null  object
#  10  photo_filename    34756 non-null  object
#  11  photo_credit      34756 non-null  object
#  12  author_name       34756 non-null  object
#  13  date_published    34756 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(1), int64(2), object(10)
# memory usage: 3.7+ MB

# %%
epic_dataframe = pd.read_json(data_path, typ="frame")

dfpp.preprocess_dataframe(df=epic_dataframe)
epic_dataframe.head(10)
# Out:
#                                                                         dek  \
# id
# 54a2b6b019925f464b373351  How does fried chicken achieve No. 1 status? B...
# 54a408a019925f464b3733bc                                Spinaci all'Ebraica
# 54a408a26529d92b2c003631  This majestic, moist, and richly spiced honey ...
# 54a408a66529d92b2c003638  The idea for this sandwich came to me when my ...
# 54a408a719925f464b3733cc  In 1930, Simon Agranat, the chief justice of t...
# 54a408a919925f464b3733d3  Although Nelly Custis omitted sugar in her rec...
# 54a408aa19925f464b3733d6  Editor's note: This recipe is adapted with per...
# 54a408ab19925f464b3733da  Editor's note: This recipe is reprinted with p...
# 54a408ac19925f464b3733de  Editor's note: This recipe is reprinted with p...
# 54a408ac6529d92b2c003653  Editor's note: This recipe is reprinted with p...
#
#                                                             hed  \
# id
# 54a2b6b019925f464b373351            Pickle-Brined Fried Chicken
# 54a408a019925f464b3733bc                   Spinach Jewish Style
# 54a408a26529d92b2c003631                  New Year’s Honey Cake
# 54a408a66529d92b2c003638  The B.L.A.Bagel with Lox and Avocado
# 54a408a719925f464b3733cc        Shakshuka a la Doktor Shakshuka
# 54a408a919925f464b3733d3                          Rice Pancakes
# 54a408aa19925f464b3733d6                        Jack-O'-Lantern
# 54a408ab19925f464b3733da                  Seven-Minute Frosting
# 54a408ac19925f464b3733de                  Creamy White Frosting
# 54a408ac6529d92b2c003653                         Host of Ghosts
#
#                           aggregateRating  \
# id
# 54a2b6b019925f464b373351             3.11
# 54a408a019925f464b3733bc             3.22
# 54a408a26529d92b2c003631             3.62
# 54a408a66529d92b2c003638             4.00
# 54a408a719925f464b3733cc             2.71
# 54a408a919925f464b3733d3             0.00
# 54a408aa19925f464b3733d6             1.00
# 54a408ab19925f464b3733da             3.53
# 54a408ac19925f464b3733de             2.00
# 54a408ac6529d92b2c003653             3.17
#
#                                                                 ingredients  \
# id
# 54a2b6b019925f464b373351  [1 tablespoons yellow mustard seeds, 1 tablesp...
# 54a408a019925f464b3733bc  [3 pounds small-leaved bulk spinach, Salt, 1/2...
# 54a408a26529d92b2c003631  [3 1/2 cups all-purpose flour, 1 tablespoon ba...
# 54a408a66529d92b2c003638  [1 small ripe avocado, preferably Hass (see No...
# 54a408a719925f464b3733cc  [2 pounds fresh tomatoes, unpeeled and cut in ...
# 54a408a919925f464b3733d3  [1 1/2 cups cooked rice, 2 cups heavy cream, 2...
# 54a408aa19925f464b3733d6  [2 tablespoons shortening, 2 tablespoons flour...
# 54a408ab19925f464b3733da  [1 1/2 cups sugar, 1/3 cup cold water, 2 egg w...
# 54a408ac19925f464b3733de  [1 cup vegetable shortening, 1 1/2 teaspoons v...
# 54a408ac6529d92b2c003653  [One purchased 9-inch angel food cake, 2 recip...
#
#                                                                   prepSteps  \
# id
# 54a2b6b019925f464b373351  [Toast mustard and coriander seeds in a dry me...
# 54a408a019925f464b3733bc  [Remove the stems and roots from the spinach. ...
# 54a408a26529d92b2c003631  [I like this cake best baked in a 9-inch angel...
# 54a408a66529d92b2c003638  [A short time before serving, mash avocado and...
# 54a408a719925f464b3733cc  [1. Place the tomatoes, garlic, salt, paprika,...
# 54a408a919925f464b3733d3  [1. Combine the rice, cream, and butter. Add t...
# 54a408aa19925f464b3733d6  [1. Preheat the oven to 350°F. Lightly grease ...
# 54a408ab19925f464b3733da  [1. Combine the sugar, water, egg whites, and ...
# 54a408ac19925f464b3733de  [1. With a mixer on medium speed, beat togethe...
# 54a408ac6529d92b2c003653  [1. Place the cake on the cake plate. Reserve ...
#
#                           reviewsCount  willMakeAgainPct     cuisine_name  \
# id
# 54a2b6b019925f464b373351             7               100  Missing Cuisine
# 54a408a019925f464b3733bc             5                80          Italian
# 54a408a26529d92b2c003631           105                88           Kosher
# 54a408a66529d92b2c003638             7               100           Kosher
# 54a408a719925f464b3733cc             7                83           Kosher
# 54a408a919925f464b3733d3             0                 0  Missing Cuisine
# 54a408aa19925f464b3733d6             1                 0  Missing Cuisine
# 54a408ab19925f464b3733da             8                75  Missing Cuisine
# 54a408ac19925f464b3733de             5                 0  Missing Cuisine
# 54a408ac6529d92b2c003653            12               100  Missing Cuisine
#
#                                                photo_filename  \
# id
# 54a2b6b019925f464b373351       51247610_fried-chicken_1x1.jpg
# 54a408a019925f464b3733bc  EP_12162015_placeholders_rustic.jpg
# 54a408a26529d92b2c003631          EP_09022015_honeycake-2.jpg
# 54a408a66529d92b2c003638  EP_12162015_placeholders_casual.jpg
# 54a408a719925f464b3733cc  EP_12162015_placeholders_formal.jpg
# 54a408a919925f464b3733d3  EP_12162015_placeholders_formal.jpg
# 54a408aa19925f464b3733d6                           350068.jpg
# 54a408ab19925f464b3733da  EP_12162015_placeholders_bright.jpg
# 54a408ac19925f464b3733de  EP_12162015_placeholders_casual.jpg
# 54a408ac6529d92b2c003653                           350067.jpg
#
#                                                                photo_credit  \
# id
# 54a2b6b019925f464b373351                Michael Graydon and Nikole Herriott
# 54a408a019925f464b3733bc  Photo by Chelsea Kyle, Prop Styling by Anna St...
# 54a408a26529d92b2c003631  Photo by Chelsea Kyle, Food Styling by Anna St...
# 54a408a66529d92b2c003638  Photo by Chelsea Kyle, Prop Styling by Rhoda B...
# 54a408a719925f464b3733cc  Photo by Chelsea Kyle, Prop Styling by Rhoda B...
# 54a408a919925f464b3733d3  Photo by Chelsea Kyle, Prop Styling by Rhoda B...
# 54a408aa19925f464b3733d6                             Jennifer Newberry Mead
# 54a408ab19925f464b3733da  Photo by Chelsea Kyle, Prop Styling by Anna St...
# 54a408ac19925f464b3733de  Photo by Chelsea Kyle, Prop Styling by Rhoda B...
# 54a408ac6529d92b2c003653                             Jennifer Newberry Mead
#
#                                   author_name            date_published  \
# id
# 54a2b6b019925f464b373351  Missing Author Name 2014-08-19 04:00:00+00:00
# 54a408a019925f464b3733bc   Edda Servi Machlin 2008-09-09 04:00:00+00:00
# 54a408a26529d92b2c003631        Marcy Goldman 2008-09-10 04:00:00+00:00
# 54a408a66529d92b2c003638            Faye Levy 2008-09-08 04:00:00+00:00
# 54a408a719925f464b3733cc          Joan Nathan 2008-09-09 04:00:00+00:00
# 54a408a919925f464b3733d3    Stephen A. McLeod 2012-02-17 04:00:00+00:00
# 54a408aa19925f464b3733d6         Matthew Mead 2008-09-09 04:00:00+00:00
# 54a408ab19925f464b3733da         Matthew Mead 2008-09-09 04:00:00+00:00
# 54a408ac19925f464b3733de         Matthew Mead 2008-09-09 04:00:00+00:00
# 54a408ac6529d92b2c003653         Matthew Mead 2008-09-09 04:00:00+00:00
#
#                                                                  recipe_url
# id
# 54a2b6b019925f464b373351  https://www.epicurious.com/recipes/food/views/...
# 54a408a019925f464b3733bc  https://www.epicurious.com/recipes/food/views/...
# 54a408a26529d92b2c003631  https://www.epicurious.com/recipes/food/views/...
# 54a408a66529d92b2c003638  https://www.epicurious.com/recipes/food/views/...
# 54a408a719925f464b3733cc  https://www.epicurious.com/recipes/food/views/...
# 54a408a919925f464b3733d3  https://www.epicurious.com/recipes/food/views/...
# 54a408aa19925f464b3733d6  https://www.epicurious.com/recipes/food/views/...
# 54a408ab19925f464b3733da  https://www.epicurious.com/recipes/food/views/...
# 54a408ac19925f464b3733de  https://www.epicurious.com/recipes/food/views/...
# 54a408ac6529d92b2c003653  https://www.epicurious.com/recipes/food/views/...

# %%
epic_dataframe["recipe_url"][0]
# Out:
# 'https://www.epicurious.com/recipes/food/views/pickle-brined-fried-chicken-51247610'

# %% [markdown]
# ### Next Steps
#
# Since this seems to be working, expand EDA into another notebook looking at CountVectorization

# %% [markdown]
# # core
#
# > test

# %% [markdown]
# # | default_exp core

# %%
# | hide
from nbdev.showdoc import *

# %% [markdown]
# # | export
# def foo():
#     pass

# %%
# | hide
import nbdev

nbdev.nbdev_export()

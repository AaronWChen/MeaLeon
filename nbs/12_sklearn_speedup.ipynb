# %% [raw]
# ---
# description: test
# output-file: template.html
# title: Template
#
# ---

# %% [markdown]
# # | default_exp core

# %%
# | hide
# from bertopic import BERTopic
# from bertopic.vectorizers import OnlineCountVectorizer
import dagshub
from datetime import datetime
import dill as pickle
import dvc.api
# from hdbscan import HDBSCAN
from itertools import tee, islice, product
import joblib
# import mlflow
# from mlflow.models import infer_signature
import nbdev
from nbdev.showdoc import *
import pandas as pd
import re
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import (
    CountVectorizer
    , TfidfTransformer
    , TfidfVectorizer
    , 
)
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
# from src.custom_sklearn_text_transformer_mlflow import CustomSKLearnAnalyzer
# from src.custom_stanza_mlflow import CustomSKLearnWrapper
import src.dataframe_preprocessor as dfpp
import stanza
from tqdm import tqdm
# from umap import UMAP

# %%
# !export 'PYTORCH_CUDA_ALLOC_CONF=max_split_size_mb:128'

# %% [markdown]
# # | export

# %%
def stanza_analyzer(stanza_pipeline, minNgramLength, maxNgramLength):
        """
        Custom ngram analyzer function, matching only ngrams that belong to the same line

        The source for this was StackOverflow because I couldn't figure out how to let sklearn pipelines use arguments for custom analyzers

        Use this as the analyzer for an sklearn pipeline, and it should work

        Args:
            stanza_pipeline: Stanza pipeline
            minNgramLength: integer for the minimum ngram (usually 1)
            maxNgramLength: integer for maximum length ngram (usually should not exceed 4)

        Returns:
            A function that will be used in sklearn pipeline. Said function yields a generator

        """
        # print("text processing start: " + str(datetime.now()))

        def ngrams_per_line(word_list):
            # Time O(n)
            lowered = " brk ".join(
                 map(str,
                     [word
                      if word is not None
                      else ''
                      for word in word_list
                      ]
                    )
            ).lower()

            if lowered is None:
                lowered = "Missing ingredients"

            # print("Stanza processing start: " + str(datetime.now()))
            
            # Time O(n)
            preproc = stanza_pipeline(lowered)

            # print("Stanza processing end/lemmatizing start: " + str(datetime.now()))
            
            # Suspicion that this is O(n^2)
            lemmad = " ".join(
                 map(
                      str, 
                        [
                           word.lemma
                           for sent in preproc.sentences
                           for word in sent.words
                           if (
                                word.upos
                                not in ["NUM", "DET", "ADV", "CCONJ", "ADP", "SCONJ"]
                                and word is not None
                                )
                        ],
                 )
            )
                        
            
            # print("Stanza lemmatizing end: " + str(datetime.now()))

            # analyze each line of the input string seperately
            # Time O(word^ngram max)
            for ln in lemmad.split(" brk "):

                # tokenize the input string (customize the regex as desired)
                at_least_two_english_characters_whole_words = "(?u)\b[a-zA-Z]{2,}\b"
                terms = re.split(at_least_two_english_characters_whole_words, ln)

                # loop ngram creation for every number between min and max ngram length
                for ngramLength in range(minNgramLength, maxNgramLength + 1):

                    # find and return all ngrams
                    # for ngram in zip(*[terms[i:] for i in range(3)]):
                    # <-- solution without a generator (works the same but has higher memory usage)
                    for ngram in zip(
                        *[
                            islice(seq, i, len(terms))
                            for i, seq in enumerate(tee(terms, ngramLength))
                        ]
                    ):  # <-- solution using a generator

                        ngram = " ".join(map(str, ngram))
                        yield ngram

        # print("n_gram creation end: " + str(datetime.now()))
        return ngrams_per_line

# %%
def groq_mixtral_analyzer(stanza_pipeline, minNgramLength, maxNgramLength):
        """
        Custom ngram analyzer function, matching only ngrams that belong to the same line

        The source for this was StackOverflow because I couldn't figure out how to let sklearn pipelines use arguments for custom analyzers

        Use this as the analyzer for an sklearn pipeline, and it should work

        Args:
            stanza_pipeline: Stanza pipeline
            minNgramLength: integer for the minimum ngram (usually 1)
            maxNgramLength: integer for maximum length ngram (usually should not exceed 4)

        Returns:
            A function that will be used in sklearn pipeline. Said function yields a generator

        """
        # print("text processing start: " + str(datetime.now()))

        def ngrams_per_line(word_list):
            # Time O(n)
            lowered = " brk ".join(
                 map(str,
                     [word
                      if word is not None
                      else ''
                      for word in word_list
                      ]
                    )
            ).lower()

            if lowered is None:
                lowered = "Missing ingredients"

            # Time O(n)
            preproc = stanza_pipeline(lowered)

            # Suspicion that this is O(n^2)
            lemmad = " ".join(
                 map(
                      str, 
                        [
                           word.lemma
                           for sent in preproc.sentences
                           for word in sent.words
                           if (
                                word.upos
                                not in ["NUM", "DET", "ADV", "CCONJ", "ADP", "SCONJ"]
                                and word is not None
                                )
                        ],
                 )
            )
                        
            # analyze each line of the input string seperately
            # Time O(word^ngram max)
            for ln in lemmad.split(" brk "):

                # tokenize the input string (customize the regex as desired)
                at_least_two_english_characters_whole_words = "(?u)\b[a-zA-Z]{2,}\b"
                terms = re.split(at_least_two_english_characters_whole_words, ln)

                # loop ngram creation for every number between min and max ngram length
                for ngram_length in range(minNgramLength, maxNgramLength + 1):
                    ngrams = zip(*[seq[i:] for i in range(ngram_length)])
                    for ngram in map(" ".join, ngrams):
                        yield ngram

        # print("n_gram creation end: " + str(datetime.now()))
        return ngrams_per_line

# %%
def groq_llama2_analyzer(stanza_pipeline, minNgramLength, maxNgramLength):
        """
        Custom ngram analyzer function, matching only ngrams that belong to the same line

        The source for this was StackOverflow because I couldn't figure out how to let sklearn pipelines use arguments for custom analyzers

        Use this as the analyzer for an sklearn pipeline, and it should work

        Args:
            stanza_pipeline: Stanza pipeline
            minNgramLength: integer for the minimum ngram (usually 1)
            maxNgramLength: integer for maximum length ngram (usually should not exceed 4)

        Returns:
            A function that will be used in sklearn pipeline. Said function yields a generator

        """
        # print("text processing start: " + str(datetime.now()))

        def ngrams_per_line(word_list):
            # Time O(n)
            lowered = " brk ".join(
                 map(str,
                     [word
                      if word is not None
                      else ''
                      for word in word_list
                      ]
                    )
            ).lower()

            if lowered is None:
                lowered = "Missing ingredients"

            # Time O(n)
            preproc = stanza_pipeline(lowered)

            # Suspicion that this is O(n^2)
            lemmad = " ".join(
                 map(
                      str, 
                        [
                           word.lemma
                           for sent in preproc.sentences
                           for word in sent.words
                           if (
                                word.upos
                                not in ["NUM", "DET", "ADV", "CCONJ", "ADP", "SCONJ"]
                                and word is not None
                                )
                        ],
                 )
            )
                        
            # analyze each line of the input string seperately
            # Time O(word^ngram max)
            for ln in lemmad.split(" brk "):
                terms = re.split(r"\b[a-zA-Z]{2,}\b", ln)
                for ngram_length in range(minNgramLength, maxNgramLength + 1):
                    for ngram in product(*[terms[i:] for i in range(ngram_length)]):
                        yield " ".join(map(str, ngram))

        # print("n_gram creation end: " + str(datetime.now()))
        return ngrams_per_line

# %%
def claude_analyzer(stanza_pipeline, minNgramLength, maxNgramLength):
        """
        Custom ngram analyzer function, matching only ngrams that belong to the same line

        The source for this was StackOverflow because I couldn't figure out how to let sklearn pipelines use arguments for custom analyzers

        Use this as the analyzer for an sklearn pipeline, and it should work

        Args:
            stanza_pipeline: Stanza pipeline
            minNgramLength: integer for the minimum ngram (usually 1)
            maxNgramLength: integer for maximum length ngram (usually should not exceed 4)

        Returns:
            A function that will be used in sklearn pipeline. Said function yields a generator

        """
        # print("text processing start: " + str(datetime.now()))

        def ngrams_per_line(word_list):
            # Time O(n)
            lowered = " brk ".join(
                 map(str,
                     [word
                      if word is not None
                      else ''
                      for word in word_list
                      ]
                    )
            ).lower()

            if lowered is None:
                lowered = "Missing ingredients"

            # Time O(n)
            preproc = stanza_pipeline(lowered)

            # Suspicion that this is O(n^2)
            lemmad = " ".join(
                 map(
                      str, 
                        [
                           word.lemma
                           for sent in preproc.sentences
                           for word in sent.words
                           if (
                                word.upos
                                not in ["NUM", "DET", "ADV", "CCONJ", "ADP", "SCONJ"]
                                and word is not None
                                )
                        ],
                 )
            )
                        
            # analyze each line of the input string seperately
            # Time O(word^ngram max)
            for ln in lemmad.split(" brk "):
                at_least_two_english_characters_whole_words = r"(?u)\b\w{2,}\b"
                terms = re.split(at_least_two_english_characters_whole_words, ln)

                for ngram_length in range(minNgramLength, maxNgramLength + 1):
                    # Use itertools.tee to create multiple independent iterators
                    iterators = tee(terms, ngram_length)

                    # Use itertools.islice to slice each iterator
                    for i, it in enumerate(iterators):
                        iterators[i] = islice(it, i, len(terms))

                    # Yield n-grams of the desired length
                    yield from (" ".join(ngram) for ngram in zip(*iterators))
                    
        return ngrams_per_line

# %%
def phind70b_analyzer(stanza_pipeline, minNgramLength, maxNgramLength):
        """
        Custom ngram analyzer function, matching only ngrams that belong to the same line

        The source for this was StackOverflow because I couldn't figure out how to let sklearn pipelines use arguments for custom analyzers

        Use this as the analyzer for an sklearn pipeline, and it should work

        Args:
            stanza_pipeline: Stanza pipeline
            minNgramLength: integer for the minimum ngram (usually 1)
            maxNgramLength: integer for maximum length ngram (usually should not exceed 4)

        Returns:
            A function that will be used in sklearn pipeline. Said function yields a generator

        """
        # print("text processing start: " + str(datetime.now()))

        def ngrams_per_line(word_list):
            # Time O(n)
            lowered = " brk ".join(
                 map(str,
                     [word
                      if word is not None
                      else ''
                      for word in word_list
                      ]
                    )
            ).lower()

            if lowered is None:
                lowered = "Missing ingredients"

            # Time O(n)
            preproc = stanza_pipeline(lowered)

            # Suspicion that this is O(n^2)
            lemmad = " ".join(
                 map(
                      str, 
                        [
                           word.lemma
                           for sent in preproc.sentences
                           for word in sent.words
                           if (
                                word.upos
                                not in ["NUM", "DET", "ADV", "CCONJ", "ADP", "SCONJ"]
                                and word is not None
                                )
                        ],
                 )
            )
                        
            # analyze each line of the input string seperately
            # Time O(word^ngram max)
            for ln in lemmad.split(" brk "):
                at_least_two_english_characters_whole_words = "(?u)\b[a-zA-Z]{2,}\b"
                terms = re.split(at_least_two_english_characters_whole_words, lemmad)

                # Loop n-gram creation for every number between min and max n-gram length
                for ngramLength in range(minNgramLength, maxNgramLength + 1):
                    # Use a sliding window approach to generate n-grams
                    for i in range(len(terms) - ngramLength + 1):
                        ngram = " ".join(terms[i:i+ngramLength])
                        yield ngram
                    
        return ngrams_per_line

# %%
def generate_ngrams(lemmad, minNgramLength, maxNgramLength):
    # Tokenize the input string
    at_least_two_english_characters_whole_words = "(?u)\b[a-zA-Z]{2,}\b"
    terms = re.split(at_least_two_english_characters_whole_words, lemmad)
    print(terms)

    # Loop n-gram creation for every number between min and max n-gram length
    for ngramLength in range(minNgramLength, maxNgramLength + 1):
        # Use a sliding window approach to generate n-grams
        for i in range(len(terms) - ngramLength + 1):
            ngram = " ".join(terms[i:i+ngramLength])
            print(ngram)
            yield ngram

# %%
# Example usage
lemmad = "This is a test sentence for n-gram generation."
minNgramLength = 2
maxNgramLength = 3

for ngram in generate_ngrams(lemmad, minNgramLength, maxNgramLength):
    print(ngram)

# didn't print anything
# Out:
# ['This is a test sentence for n-gram generation.']

# %%
# The print statements will be executed whenever the generator is iterated over. If you just want to see what the iterator prints, you can call it in a list comprehension without saving the result.

lemmad = "This is a test sentence for n-gram generation."
minNgramLength = 1
maxNgramLength = 3

[ngram for ngram in generate_ngrams(lemmad, minNgramLength, maxNgramLength)]
# Out:
# ['This is a test sentence for n-gram generation.']
# This is a test sentence for n-gram generation.
# ['This is a test sentence for n-gram generation.']

# %%
def stanza_analyzer_no_lemma(stanza_pipeline, minNgramLength, maxNgramLength):
        """
        Custom ngram analyzer function, matching only ngrams that belong to the same line

        The source for this was StackOverflow because I couldn't figure out how to let sklearn pipelines use arguments for custom analyzers

        Use this as the analyzer for an sklearn pipeline, and it should work

        Args:
            stanza_pipeline: Stanza pipeline
            minNgramLength: integer for the minimum ngram (usually 1)
            maxNgramLength: integer for maximum length ngram (usually should not exceed 4)

        Returns:
            A function that will be used in sklearn pipeline. Said function yields a generator

        """
        # print("text processing start: " + str(datetime.now()))

        def ngrams_per_line(word_list):
            # Time O(n)
            lowered = " brk ".join(
                 map(str,
                     [word
                      if word is not None
                      else ''
                      for word in word_list
                      ]
                    )
            ).lower()

            if lowered is None:
                lowered = "Missing ingredients"

            
            # Time O(n)
            # preproc = stanza_pipeline(lowered)

            # print("Stanza processing end/lemmatizing start: " + str(datetime.now()))
            
            # Suspicion that this is O(n^2)
            # lemmad = " ".join(
            #      map(
            #           str, 
            #             [
            #                word.lemma
            #                for sent in preproc.sentences
            #                for word in sent.words
            #                if (
            #                     word.upos
            #                     not in ["NUM", "DET", "ADV", "CCONJ", "ADP", "SCONJ"]
            #                     and word is not None
            #                     )
            #             ],
            #      )
            # )
                        
            
            # print("Stanza lemmatizing end: " + str(datetime.now()))

            # analyze each line of the input string seperately
            # Time O(word^ngram max)
            for ln in lowered.split(" brk "):

                # tokenize the input string (customize the regex as desired)
                at_least_two_english_characters_whole_words = "(?u)\b[a-zA-Z]{2,}\b"
                terms = re.split(at_least_two_english_characters_whole_words, ln)

                # loop ngram creation for every number between min and max ngram length
                for ngramLength in range(minNgramLength, maxNgramLength + 1):

                    # find and return all ngrams
                    # for ngram in zip(*[terms[i:] for i in range(3)]):
                    # <-- solution without a generator (works the same but has higher memory usage)
                    for ngram in zip(
                        *[
                            islice(seq, i, len(terms))
                            for i, seq in enumerate(tee(terms, ngramLength))
                        ]
                    ):  # <-- solution using a generator

                        ngram = " ".join(map(str, ngram))
                        yield ngram

        return ngrams_per_line

# %%
# def custom_analyzer(word_list, stanza_pipeline, minNgramLength, maxNgramLength, lemmatize=True):
#     lowered = " brk ".join([word.lower() for word in word_list if word is not None])

#     preproc = stanza_pipeline(lowered)
    
#     if lemmatize:
#         lemmad = " ".join(map(str,
#                             [word.lemma
#                             for sent in preproc.sentences 
#                             for word in sent.words if (
#                                 word.upos not in ["NUM", "DET", "ADV", "CCONJ", "ADP", "SCONJ", "PUNCT"]
#                                 and word is not None
#                             )]
#                         )
#                     )
#     else:
#         lemmad = " ".join(map(str,
#                             [word.text
#                             for sent in preproc.sentences 
#                             for word in sent.words if (
#                                 word is not None
#                             )]
#                         )
#                     )
#     # analyze each line of the input string seperately
#     for ln in lemmad.split(' brk '):
#         # tokenize the input string (customize the regex as desired)
#         at_least_two_english_characters_whole_words = "(?u)\b[a-zA-Z]{2,}\b"
#         terms = re.split(at_least_two_english_characters_whole_words, ln)

#         # loop ngram creation for every number between min and max ngram length
#         for ngramLength in range(minNgramLength, maxNgramLength+1):

#             # find and return all ngrams
#             # for ngram in zip(*[terms[i:] for i in range(3)]): 
#                 # <-- solution without a generator (works the same but has higher memory usage)
#             for ngram in zip(*[islice(seq, i, len(terms)) for i, seq in enumerate(tee(terms, ngramLength))]):   # <-- solution using a generator
                
#                 ngram = ' '.join(map(str, ngram))
#                 # yield ngram
#                 return str(ngram)

# %%
# new groq/mixtral suggestion by using entire function with external/internal
import more_itertools

def groq_mixtral_itertools_analyzer(stanza_pipeline, minNgramLength, maxNgramLength):

    def ngrams_per_line(ingredients_list):

        lowered = " brk ".join(
                map(str, [ingred for ingred in ingredients_list if ingred is not None])
            ).lower()

        if lowered is None:
            lowered = "Missing ingredients"

        preproc = stanza_pipeline(lowered)

        lemmad = " ".join(
            map(
                str,
                [
                    word.lemma
                    for sent in preproc.sentences
                    for word in sent.words
                    if (
                        word.upos
                        not in ["NUM", "DET", "ADV", "CCONJ", "ADP", "SCONJ"]
                        and word is not None
                    )
                ],
            )
        )

        for ln in lemmad.split(" brk "):

            at_least_two_english_characters_whole_words = "(?u)\b[a-zA-Z]{2,}\b"
            terms = [
                term for term in re.split(at_least_two_english_characters_whole_words, ln) if term
            ]

            for i in range(len(terms) - maxNgramLength + 1):
                ngram = terms[i : i + maxNgramLength]
                ngram = " ".join(ngram)
                yield ngram

    return ngrams_per_line

# %%
# | hide
# nbdev.nbdev_export()

# %% [markdown]
# ### Data Preparation

# %%
# instantiate stanza pipeline
stanza.download('en')
nlp = stanza.Pipeline('en', 
                    depparse_batch_size=50, 
                    depparse_min_length_to_batch_separately=50,
                    verbose=True,
                    use_gpu=False, # set to true when on cloud/not on streaming computer
                    batch_size=100
                    )

# load raw data and preprocess/clean
data = dvc.api.read(
    path='../data/recipes-en-201706/epicurious-recipes_m2.json'
    , mode='r')
raw_df = pd.read_json(data)
print('\n')
print('--------------')
print('Raw Dataframe:', end='\n')
print(raw_df.head())
print(raw_df.shape)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# 2024-03-14 21:35:14 INFO: Downloading default packages for language: en (English) ...
# 2024-03-14 21:35:15 INFO: File exists: /home/awchen/stanza_resources/en/default.zip
# 2024-03-14 21:35:18 INFO: Finished downloading models and saved to /home/awchen/stanza_resources.
# 2024-03-14 21:35:18 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# 2024-03-14 21:35:19 INFO: Loading these models for language: en (English):
# ======================================
# | Processor    | Package             |
# --------------------------------------
# | tokenize     | combined            |
# | pos          | combined_charlm     |
# | lemma        | combined_nocharlm   |
# | constituency | ptb3-revised_charlm |
# | depparse     | combined_charlm     |
# | sentiment    | sstplus             |
# | ner          | ontonotes_charlm    |
# ======================================
#
# 2024-03-14 21:35:19 INFO: Using device: cpu
# 2024-03-14 21:35:19 INFO: Loading: tokenize
# 2024-03-14 21:35:19 INFO: Loading: pos
# 2024-03-14 21:35:19 INFO: Loading: lemma
# 2024-03-14 21:35:19 INFO: Loading: constituency
# 2024-03-14 21:35:19 INFO: Loading: depparse
# 2024-03-14 21:35:20 INFO: Loading: sentiment
# 2024-03-14 21:35:20 INFO: Loading: ner
# 2024-03-14 21:35:20 INFO: Done loading processors!
# --------------
# Raw Dataframe:
#                          id  \
# 0  54a2b6b019925f464b373351
# 1  54a408a019925f464b3733bc
# 2  54a408a26529d92b2c003631
# 3  54a408a66529d92b2c003638
# 4  54a408a719925f464b3733cc
#
#                                                  dek  \
# 0  How does fried chicken achieve No. 1 status? B...
# 1                                Spinaci all'Ebraica
# 2  This majestic, moist, and richly spiced honey ...
# 3  The idea for this sandwich came to me when my ...
# 4  In 1930, Simon Agranat, the chief justice of t...
#
#                                      hed                   pubDate  \
# 0            Pickle-Brined Fried Chicken  2014-08-19T04:00:00.000Z
# 1                   Spinach Jewish Style  2008-09-09T04:00:00.000Z
# 2                  New Year’s Honey Cake  2008-09-10T04:00:00.000Z
# 3  The B.L.A.Bagel with Lox and Avocado  2008-09-08T04:00:00.000Z
# 4        Shakshuka a la Doktor Shakshuka  2008-09-09T04:00:00.000Z
#
#                              author    type  \
# 0                                []  recipe
# 1  [{'name': 'Edda Servi Machlin'}]  recipe
# 2       [{'name': 'Marcy Goldman'}]  recipe
# 3           [{'name': 'Faye Levy'}]  recipe
# 4         [{'name': 'Joan Nathan'}]  recipe
#
#                                                  url  \
# 0  /recipes/food/views/pickle-brined-fried-chicke...
# 1    /recipes/food/views/spinach-jewish-style-350152
# 2  /recipes/food/views/majestic-and-moist-new-yea...
# 3  /recipes/food/views/the-b-l-a-bagel-with-lox-a...
# 4  /recipes/food/views/shakshuka-a-la-doktor-shak...
#
#                                            photoData  \
# 0  {'id': '54a2b64a6529d92b2c003409', 'filename':...
# 1  {'id': '56746182accb4c9831e45e0a', 'filename':...
# 2  {'id': '55e85ba4cf90d6663f728014', 'filename':...
# 3  {'id': '5674617e47d1a28026045e4f', 'filename':...
# 4  {'id': '56746183b47c050a284a4e15', 'filename':...
#
#                                                  tag  aggregateRating  \
# 0  {'category': 'ingredient', 'name': 'Chicken', ...             3.11
# 1  {'category': 'cuisine', 'name': 'Italian', 'ur...             3.22
# 2  {'category': 'cuisine', 'name': 'Jewish', 'url...             3.62
# 3  {'category': 'cuisine', 'name': 'Jewish', 'url...             4.00
# 4  {'category': 'cuisine', 'name': 'Jewish', 'url...             2.71
#
#                                          ingredients  \
# 0  [1 tablespoons yellow mustard seeds, 1 tablesp...
# 1  [3 pounds small-leaved bulk spinach, Salt, 1/2...
# 2  [3 1/2 cups all-purpose flour, 1 tablespoon ba...
# 3  [1 small ripe avocado, preferably Hass (see No...
# 4  [2 pounds fresh tomatoes, unpeeled and cut in ...
#
#                                            prepSteps  reviewsCount  \
# 0  [Toast mustard and coriander seeds in a dry me...             7
# 1  [Remove the stems and roots from the spinach. ...             5
# 2  [I like this cake best baked in a 9-inch angel...           105
# 3  [A short time before serving, mash avocado and...             7
# 4  [1. Place the tomatoes, garlic, salt, paprika,...             7
#
#    willMakeAgainPct  dateCrawled
# 0               100   1498547035
# 1                80   1498547740
# 2                88   1498547738
# 3               100   1498547740
# 4                83   1498547740
# (34756, 15)

# %%
# take sample and train/test split 
subset_df = raw_df.sample(n=100, random_state=45)
train_df, test_df = train_test_split(subset_df,test_size=0.5, random_state=45)

# pre_proc_df is cleaned dataframe
to_nlp_df = dfpp.preprocess_dataframe(train_df)
print('\n')
print('--------------')
print('Preprocessed Dataframe:', end='\n')
print(to_nlp_df.head())
print(to_nlp_df.shape)

# create subset for dev purposes
# to_nlp_df = pre_proc_df
# print('\n')
# print('-' * 80)
# print('Subset Dataframe:', end='\n')
# print(to_nlp_df.head())
# print(to_nlp_df.shape)
# Out:
# --------------
# Preprocessed Dataframe:
#                                                                         dek  \
# id
# 54a4270b19925f464b37c1dc
# 54a42cde19925f464b3809d2  Green chiles pickled in soy sauce and vinegar ...
# 54a433036529d92b2c015de3  This soup features the flavors of India: aroma...
# 54a451926529d92b2c01eda8
# 54a430876529d92b2c013e2b  Brown sugar and molasses are balanced by fresh...
#
#                                                                         hed  \
# id
# 54a4270b19925f464b37c1dc  Grilled Hearts of Romaine with Blue Cheese Vin...
# 54a42cde19925f464b3809d2                              Soy-Pickled Jalapeños
# 54a433036529d92b2c015de3  Curried Potato and Spinach Soup with Onion Sal...
# 54a451926529d92b2c01eda8                                       Chicken Soup
# 54a430876529d92b2c013e2b                           Sweet-Hot Barbecue Sauce
#
#                           aggregateRating  \
# id
# 54a4270b19925f464b37c1dc             3.64
# 54a42cde19925f464b3809d2             3.43
# 54a433036529d92b2c015de3             3.00
# 54a451926529d92b2c01eda8             3.19
# 54a430876529d92b2c013e2b             0.00
#
#                                                                 ingredients  \
# id
# 54a4270b19925f464b37c1dc  [1 1/2 cups white wine vinegar, 1/2 cup sugar,...
# 54a42cde19925f464b3809d2  [3 large fresh jalapeños (4 inches), sliced 1/...
# 54a433036529d92b2c015de3  [4 cups chopped red onions (about 2 large), 1 ...
# 54a451926529d92b2c01eda8  [1 pound chicken parts, 2 stalks celery, inclu...
# 54a430876529d92b2c013e2b  [2 tablespoons olive oil, 1 cup chopped onion,...
#
#                                                                   prepSteps  \
# id
# 54a4270b19925f464b37c1dc  [Combine first 5 ingredients and 1/4 teaspoon ...
# 54a42cde19925f464b3809d2  [Combine all ingredients in a small heavy sauc...
# 54a433036529d92b2c015de3  [Combine first 5 ingredients in heavy medium s...
# 54a451926529d92b2c01eda8  [1. Pour 12 cups of cold water into a large st...
# 54a430876529d92b2c013e2b  [Heat oil in large saucepan over medium-high h...
#
#                           reviewsCount  willMakeAgainPct     cuisine_name  \
# id
# 54a4270b19925f464b37c1dc             9               100  Missing Cuisine
# 54a42cde19925f464b3809d2             6               100  Missing Cuisine
# 54a433036529d92b2c015de3             6                67           Indian
# 54a451926529d92b2c01eda8            32                87           Kosher
# 54a430876529d92b2c013e2b             0                 0  Missing Cuisine
#
#                                                photo_filename  \
# id
# 54a4270b19925f464b37c1dc  EP_12162015_placeholders_casual.jpg
# 54a42cde19925f464b3809d2  EP_12162015_placeholders_rustic.jpg
# 54a433036529d92b2c015de3                           234125.jpg
# 54a451926529d92b2c01eda8  EP_12162015_placeholders_formal.jpg
# 54a430876529d92b2c013e2b  EP_12162015_placeholders_rustic.jpg
#
#                                                                photo_credit  \
# id
# 54a4270b19925f464b37c1dc  Photo by Chelsea Kyle, Prop Styling by Rhoda B...
# 54a42cde19925f464b3809d2  Photo by Chelsea Kyle, Prop Styling by Anna St...
# 54a433036529d92b2c015de3                                      Brian Leatart
# 54a451926529d92b2c01eda8  Photo by Chelsea Kyle, Prop Styling by Rhoda B...
# 54a430876529d92b2c013e2b  Photo by Chelsea Kyle, Prop Styling by Anna St...
#
#                               author_name            date_published  \
# id
# 54a4270b19925f464b37c1dc    Kate Higgins  2010-12-16 04:00:00+00:00
# 54a42cde19925f464b3809d2     Lillian Chou 2009-02-19 04:00:00+00:00
# 54a433036529d92b2c015de3     Peter Gordon 2006-03-07 04:00:00+00:00
# 54a451926529d92b2c01eda8  Sharon Lebewohl 2004-08-20 04:00:00+00:00
# 54a430876529d92b2c013e2b   Suzanne Tracht 2007-12-03 20:11:11+00:00
#
#                                                                  recipe_url
# id
# 54a4270b19925f464b37c1dc  https://www.epicurious.com/recipes/food/views/...
# 54a42cde19925f464b3809d2  https://www.epicurious.com/recipes/food/views/...
# 54a433036529d92b2c015de3  https://www.epicurious.com/recipes/food/views/...
# 54a451926529d92b2c01eda8  https://www.epicurious.com/recipes/food/views/...
# 54a430876529d92b2c013e2b  https://www.epicurious.com/recipes/food/views/...
# (50, 13)

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {
    'analyzer': stanza_analyzer(
        stanza_pipeline=nlp,
        minNgramLength=1,
        maxNgramLength=1
        ),
    'min_df':3,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

# print('\n')
# print('-' * 80)
# print('sklearn fit transform on ingredients:', end='\n')

model_input = to_nlp_df['ingredients']

# print('\n')
# print('-' * 80)
# print('Input Data: ', end='\n')
# print(model_input)

# print('\n')
# print('-' * 80)
# print('Input Data Shape: ', end='\n')
# print(model_input.shape)

# print('\n')
# print('-' * 80)
# print('Random 3 Records from Input Data: ', end='\n')
# print(model_input.sample(3, random_state=200))

# Do fit transform on data
print("fit_transform start: " + str(datetime.now()))
response = sklearn_transformer.fit_transform(tqdm(model_input)) 
print("fit_transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)
# Out:
# fit_transform start: 2024-03-14 21:35:22.742604
# 100%|██████████| 50/50 [01:30<00:00,  1.80s/it]
# fit_transform end: 2024-03-14 21:36:52.876082

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {
    'analyzer': stanza_analyzer_no_lemma(
        stanza_pipeline=nlp,
        minNgramLength=1,
        maxNgramLength=4
        ),
    'min_df':1,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

# print('\n')
# print('-' * 80)
# print('sklearn fit transform on ingredients:', end='\n')

model_input = to_nlp_df['ingredients']

# print('\n')
# print('-' * 80)
# print('Input Data: ', end='\n')
# print(model_input)

# print('\n')
# print('-' * 80)
# print('Input Data Shape: ', end='\n')
# print(model_input.shape)

# print('\n')
# print('-' * 80)
# print('Random 3 Records from Input Data: ', end='\n')
# print(model_input.sample(3, random_state=200))

# Do fit transform on data
print("fit_transform start: " + str(datetime.now()))
response = sklearn_transformer.fit_transform(tqdm(model_input)) 
print("fit_transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)
# Out:
# fit_transform start: 2024-03-14 21:36:52.913984
# 100%|██████████| 50/50 [00:00<00:00, 12807.04it/s]
# fit_transform end: 2024-03-14 21:36:52.925909

# %%
transformed_recipe
# Out:
#                                     \
# id
# 54a4270b19925f464b37c1dc  0.000000
# 54a42cde19925f464b3809d2  0.000000
# 54a433036529d92b2c015de3  0.000000
# 54a451926529d92b2c01eda8  0.000000
# 54a430876529d92b2c013e2b  0.000000
# 54a453df6529d92b2c020687  0.000000
# 55b0e7116284773353bf4580  0.000000
# 54a42bab6529d92b2c00ffa7  0.000000
# 54a4748f19925f464b399ef2  0.000000
# 54a4356a19925f464b3875bb  0.399821
# 54a4697e6529d92b2c0279d3  0.000000
# 54a45e426529d92b2c02488f  0.000000
# 54a452c96529d92b2c01f889  0.000000
# 54a4323619925f464b384bcc  0.000000
# 54a4259119925f464b37af9c  0.000000
# 54a431da6529d92b2c014ee9  0.000000
# 54a426fd19925f464b37c125  0.000000
# 54a47bb019925f464b39b9b7  0.260476
# 54a434d819925f464b386e62  0.244309
# 54a428116529d92b2c00d1a7  0.260476
# 54a436036529d92b2c01859e  0.000000
# 54a47edf19925f464b39c58d  0.000000
# 54a419706529d92b2c006650  0.000000
# 54a4349619925f464b386b12  0.000000
# 54a4340f6529d92b2c016be8  0.000000
# 54a40e546529d92b2c004606  0.000000
# 54a428b419925f464b37d5ce  0.000000
# 54a453a519925f464b38fd16  0.000000
# 54a41cb219925f464b376d82  0.000000
# 54a431896529d92b2c014b27  0.000000
# 54a423ab19925f464b3799f2  0.000000
# 54a47c1419925f464b39bb28  0.000000
# 593ee3ba12c27b182380821f  0.000000
# 54a456366529d92b2c02235a  0.000000
# 54a452d419925f464b38f1b5  0.000000
# 54a4659b6529d92b2c026a53  0.000000
# 54a46d5d19925f464b3982d3  0.000000
# 54a4582119925f464b3927a1  0.000000
# 54a4205319925f464b377c9f  0.000000
# 54a470cc19925f464b39906b  0.000000
# 54a44f4a6529d92b2c01de45  0.000000
# 592ef494ae10ad089795ebfa  0.000000
# 54a41f016529d92b2c00757d  0.000000
# 54a436266529d92b2c01876e  0.199277
# 54a428bd19925f464b37d63e  0.000000
# 54a45a4f6529d92b2c0234d1  0.000000
# 54a41ed76529d92b2c007440  0.000000
# 54a42c906529d92b2c010b74  0.222612
# 569519a6dc18ea6c22c9b9ab  0.000000
# 54a438d56529d92b2c019648  0.000000
#
#                           *available at natural foods stores, juice bars, and some specialty foods shops  \
# id
# 54a4270b19925f464b37c1dc                                           0.000000
# 54a42cde19925f464b3809d2                                           0.000000
# 54a433036529d92b2c015de3                                           0.000000
# 54a47bb019925f464b39b9b7                       0.0
# 54a434d819925f464b386e62                       0.0
# 54a428116529d92b2c00d1a7                       0.0
# 54a436036529d92b2c01859e                       0.0
# 54a47edf19925f464b39c58d                       0.0
# 54a419706529d92b2c006650                       0.0
# 54a4349619925f464b386b12                       0.0
# 54a4340f6529d92b2c016be8                       0.0
# 54a40e546529d92b2c004606                       0.0
# 54a428b419925f464b37d5ce                       0.0
# 54a453a519925f464b38fd16                       0.0
# 54a41cb219925f464b376d82                       0.0
# 54a431896529d92b2c014b27                       0.0
# 54a423ab19925f464b3799f2                       0.0
# 54a47c1419925f464b39bb28                       0.0
# 593ee3ba12c27b182380821f                       0.0
# 54a456366529d92b2c02235a                       0.0
# 54a452d419925f464b38f1b5                       0.0
# 54a4659b6529d92b2c026a53                       0.0
# 54a46d5d19925f464b3982d3                       0.0
# 54a4582119925f464b3927a1                       0.0
# 54a4205319925f464b377c9f                       0.0
# 54a470cc19925f464b39906b                       0.0
# 54a44f4a6529d92b2c01de45                       0.0
# 592ef494ae10ad089795ebfa                       0.0
# 54a41f016529d92b2c00757d                       0.0
# 54a436266529d92b2c01876e                       0.0
# 54a428bd19925f464b37d63e                       0.0
# 54a45a4f6529d92b2c0234d1                       0.0
# 54a41ed76529d92b2c007440                       0.0
# 54a42c906529d92b2c010b74                       0.0
# 569519a6dc18ea6c22c9b9ab                       0.0
# 54a438d56529d92b2c019648                       0.0
#
# [50 rows x 452 columns]

# %%
print(transformed_recipe.columns)
# Out:
# Index(['',
#        '*available at natural foods stores, juice bars, and some specialty foods shops',
#        '*available online and from suppliers of british products.',
#        '*pink pickled ginger slices are available at asian markets and also at some specialty foods stores.',
#        '1 (12-inch-long) loaf of italian bread (about 2 to 3 inches in diameter), cut into 20 slices, about 1/2 inch thick',
#        '1 (7-ounce) jar roasted red bell peppers, drained, patted dry, and cut into thin strips',
#        '1 (8)-ounce package halloumi cheese',
#        '1 1-pound unpeeled eggplant, cut into 3/4-inch cubes',
#        '1 1/2 cups (6 oz) pecans, toasted and chopped',
#        '1 1/2 cups chopped onion',
#        ...
#        'salt', 'salt and freshly ground black pepper',
#        'salt and freshly ground black pepper, to taste',
#        'salt to rub inside chicken',
#        'special equipment: 2 muffin tins, each with 12 (1/2-cup) muffin cups',
#        'special equipment: a japanese benriner or other adjustable-blade slicer; a nonstick bakeware liner such as silpat',
#        'special equipment: large ceramic heatproof bowl or 8 (8-ounce) ramekins, parchment paper',
#        'unsalted butter, softened, for spreading on the biscuits',
#        'vanilla or espresso whipped buttercream', 'vegetable oil for frying'],
#       dtype='object', length=452)

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {
    'analyzer': 'word',
    'ngram_range': (1,1),
    'min_df':3,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

# print('\n')
# print('-' * 80)
# print('sklearn fit transform on ingredients:', end='\n')

model_input = to_nlp_df['ingredients'].apply(" ".join).str.lower()

# print('\n')
# print('-' * 80)
# print('Input Data: ', end='\n')
# print(model_input)

# print('\n')
# print('-' * 80)
# print('Input Data Shape: ', end='\n')
# print(model_input.shape)

# print('\n')
# print('-' * 80)
# print('Random 3 Records from Input Data: ', end='\n')
# print(model_input.sample(3, random_state=200))

print("sklearn fit transform start: " + str(datetime.now()))
# Do fit transform on data
response = sklearn_transformer.fit_transform(tqdm(model_input)) 
print("sklearn fit transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)
# Out:
# sklearn fit transform start: 2024-03-14 21:36:53.157714
# 100%|██████████| 50/50 [00:00<00:00, 29094.78it/s]
# sklearn fit transform end: 2024-03-14 21:36:53.167581

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {
    'analyzer': stanza_analyzer(
        stanza_pipeline=nlp,
        minNgramLength=1,
        maxNgramLength=2
        ),
    'min_df':3,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

# print('\n')
# print('-' * 80)
# print('sklearn fit transform on ingredients:', end='\n')

model_input = to_nlp_df['ingredients']

# print('\n')
# print('-' * 80)
# print('Input Data: ', end='\n')
# print(model_input)

# print('\n')
# print('-' * 80)
# print('Input Data Shape: ', end='\n')
# print(model_input.shape)

# print('\n')
# print('-' * 80)
# print('Random 3 Records from Input Data: ', end='\n')
# print(model_input.sample(3, random_state=200))

# Do fit transform on data
print("fit_transform start: " + str(datetime.now()))
response = sklearn_transformer.fit_transform(tqdm(model_input)) 
print("fit_transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)
# Out:
# fit_transform start: 2024-03-14 21:36:53.217712
# 100%|██████████| 50/50 [01:27<00:00,  1.74s/it]
# fit_transform end: 2024-03-14 21:38:20.419104

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {
    'analyzer': stanza_analyzer_no_lemma(
        stanza_pipeline=nlp,
        minNgramLength=1,
        maxNgramLength=2
        ),
    'min_df':3,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

# print('\n')
# print('-' * 80)
# print('sklearn fit transform on ingredients:', end='\n')

model_input = to_nlp_df['ingredients']

# print('\n')
# print('-' * 80)
# print('Input Data: ', end='\n')
# print(model_input)

# print('\n')
# print('-' * 80)
# print('Input Data Shape: ', end='\n')
# print(model_input.shape)

# print('\n')
# print('-' * 80)
# print('Random 3 Records from Input Data: ', end='\n')
# print(model_input.sample(3, random_state=200))

# Do fit transform on data
print("fit_transform start: " + str(datetime.now()))
response = sklearn_transformer.fit_transform(tqdm(model_input)) 
print("fit_transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)
# Out:
# fit_transform start: 2024-03-14 21:38:20.459487
# 100%|██████████| 50/50 [00:00<00:00, 11706.78it/s]
# fit_transform end: 2024-03-14 21:38:20.474049

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {
    'analyzer': 'word',
    'ngram_range': (1,2),
    'min_df':3,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

# print('\n')
# print('-' * 80)
# print('sklearn fit transform on ingredients:', end='\n')

model_input = to_nlp_df['ingredients'].apply(" ".join).str.lower()

# print('\n')
# print('-' * 80)
# print('Input Data: ', end='\n')
# print(model_input)

# print('\n')
# print('-' * 80)
# print('Input Data Shape: ', end='\n')
# print(model_input.shape)

# print('\n')
# print('-' * 80)
# print('Random 3 Records from Input Data: ', end='\n')
# print(model_input.sample(3, random_state=200))

print("sklearn fit transform start: " + str(datetime.now()))

# Do fit transform on data
response = sklearn_transformer.fit_transform(tqdm(model_input)) 

print("sklearn fit transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)
# Out:
# sklearn fit transform start: 2024-03-14 21:38:20.585796
# 100%|██████████| 50/50 [00:00<00:00, 18833.88it/s]
# sklearn fit transform end: 2024-03-14 21:38:20.596450

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {
    'analyzer': stanza_analyzer(
        stanza_pipeline=nlp,
        minNgramLength=1,
        maxNgramLength=3
        ),
    'min_df':3,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

# print('\n')
# print('-' * 80)
# print('sklearn fit transform on ingredients:', end='\n')

model_input = to_nlp_df['ingredients']

# print('\n')
# print('-' * 80)
# print('Input Data: ', end='\n')
# print(model_input)

# print('\n')
# print('-' * 80)
# print('Input Data Shape: ', end='\n')
# print(model_input.shape)

# print('\n')
# print('-' * 80)
# print('Random 3 Records from Input Data: ', end='\n')
# print(model_input.sample(3, random_state=200))

# Do fit transform on data
print("fit_transform start: " + str(datetime.now()))
response = sklearn_transformer.fit_transform(tqdm(model_input)) 
print("fit_transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)
# Out:
# fit_transform start: 2024-03-14 21:38:20.642642
# 100%|██████████| 50/50 [01:26<00:00,  1.72s/it]
# fit_transform end: 2024-03-14 21:39:46.863232

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {
    'analyzer': stanza_analyzer_no_lemma(
        stanza_pipeline=nlp,
        minNgramLength=1,
        maxNgramLength=3
        ),
    'min_df':3,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

# print('\n')
# print('-' * 80)
# print('sklearn fit transform on ingredients:', end='\n')

model_input = to_nlp_df['ingredients']

# print('\n')
# print('-' * 80)
# print('Input Data: ', end='\n')
# print(model_input)

# print('\n')
# print('-' * 80)
# print('Input Data Shape: ', end='\n')
# print(model_input.shape)

# print('\n')
# print('-' * 80)
# print('Random 3 Records from Input Data: ', end='\n')
# print(model_input.sample(3, random_state=200))

# Do fit transform on data
print("fit_transform start: " + str(datetime.now()))
response = sklearn_transformer.fit_transform(tqdm(model_input)) 
print("fit_transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)

print(transformed_recipe)
print(transformed_recipe.columns)
# Out:
# fit_transform start: 2024-03-14 21:39:46.886571
# 100%|██████████| 50/50 [00:00<00:00, 15050.61it/s]
# fit_transform end: 2024-03-14 21:39:46.896780
#                                     1 teaspoon vanilla extract  \
# id
# 54a4270b19925f464b37c1dc  0.000000                    0.000000
# 54a42cde19925f464b3809d2  0.000000                    0.000000
# 54a433036529d92b2c015de3  0.000000                    0.000000
# 54a451926529d92b2c01eda8  0.000000                    0.000000
# 54a430876529d92b2c013e2b  0.000000                    0.000000
# 54a453df6529d92b2c020687  0.000000                    0.000000
# 55b0e7116284773353bf4580  0.000000                    0.000000
# 54a42bab6529d92b2c00ffa7  0.000000                    0.000000
# 54a4748f19925f464b399ef2  0.000000                    0.000000
# 54a4356a19925f464b3875bb  0.873865                    0.000000
# 54a4697e6529d92b2c0279d3  0.000000                    0.000000
# 54a45e426529d92b2c02488f  0.000000                    0.000000
# 54a452c96529d92b2c01f889  0.000000                    0.000000
# 54a4323619925f464b384bcc  0.000000                    0.000000
# 54a4259119925f464b37af9c  0.000000                    0.000000
# 54a431da6529d92b2c014ee9  0.000000                    0.000000
# 54a426fd19925f464b37c125  0.000000                    0.000000
# 54a47bb019925f464b39b9b7  1.000000                    0.000000
# 54a434d819925f464b386e62  1.000000                    0.000000
# 54a428116529d92b2c00d1a7  1.000000                    0.000000
# 54a436036529d92b2c01859e  0.000000                    0.000000
# 54a47edf19925f464b39c58d  0.000000                    0.000000
# 54a419706529d92b2c006650  0.000000                    0.000000
# 54a4349619925f464b386b12  0.000000                    1.000000
# 54a4340f6529d92b2c016be8  0.000000                    0.000000
# 54a40e546529d92b2c004606  0.000000                    0.000000
# 54a428b419925f464b37d5ce  0.000000                    1.000000
# 54a453a519925f464b38fd16  0.000000                    0.000000
# 54a41cb219925f464b376d82  0.000000                    0.000000
# 54a431896529d92b2c014b27  0.000000                    0.000000
# 54a423ab19925f464b3799f2  0.000000                    0.000000
# 54a47c1419925f464b39bb28  0.000000                    0.000000
# 593ee3ba12c27b182380821f  0.000000                    0.000000
# 54a456366529d92b2c02235a  0.000000                    0.000000
# 54a452d419925f464b38f1b5  0.000000                    0.000000
# 54a4659b6529d92b2c026a53  0.000000                    0.000000
# 54a46d5d19925f464b3982d3  0.000000                    0.000000
# 54a4582119925f464b3927a1  0.000000                    0.000000
# 54a4205319925f464b377c9f  0.000000                    0.000000
# 54a470cc19925f464b39906b  0.000000                    0.000000
# 54a44f4a6529d92b2c01de45  0.000000                    0.000000
# 592ef494ae10ad089795ebfa  0.000000                    0.000000
# 54a45e426529d92b2c02488f                 0.000000
# 54a452c96529d92b2c01f889                 0.000000
# 54a4323619925f464b384bcc                 0.000000
# 54a4259119925f464b37af9c                 0.000000
# 54a431da6529d92b2c014ee9                 0.000000
# 54a426fd19925f464b37c125                 0.000000
# 54a47bb019925f464b39b9b7                 0.000000
# 54a434d819925f464b386e62                 0.000000
# 54a428116529d92b2c00d1a7                 0.000000
# 54a436036529d92b2c01859e                 0.000000
# 54a47edf19925f464b39c58d                 0.000000
# 54a419706529d92b2c006650                 0.000000
# 54a4349619925f464b386b12                 0.000000
# 54a4340f6529d92b2c016be8                 0.000000
# 54a40e546529d92b2c004606                 0.000000
# 54a428b419925f464b37d5ce                 0.000000
# 54a453a519925f464b38fd16                 0.000000
# 54a41cb219925f464b376d82                 0.000000
# 54a431896529d92b2c014b27                 0.000000
# 54a423ab19925f464b3799f2                 0.000000
# 54a47c1419925f464b39bb28                 0.000000
# 593ee3ba12c27b182380821f                 0.000000
# 54a456366529d92b2c02235a                 1.000000
# 54a452d419925f464b38f1b5                 0.000000
# 54a4659b6529d92b2c026a53                 0.000000
# 54a46d5d19925f464b3982d3                 0.000000
# 54a4582119925f464b3927a1                 0.000000
# 54a4205319925f464b377c9f                 0.000000
# 54a470cc19925f464b39906b                 0.000000
# 54a44f4a6529d92b2c01de45                 0.000000
# 592ef494ae10ad089795ebfa                 0.000000
# 54a41f016529d92b2c00757d                 0.000000
# 54a436266529d92b2c01876e                 0.000000
# 54a428bd19925f464b37d63e                 0.000000
# 54a45a4f6529d92b2c0234d1                 0.000000
# 54a41ed76529d92b2c007440                 0.000000
# 54a42c906529d92b2c010b74                 0.000000
# 569519a6dc18ea6c22c9b9ab                 0.000000
# 54a438d56529d92b2c019648                 0.000000
# Index(['', '1 teaspoon vanilla extract', '1/2 cup olive oil', '1/2 cup sugar',
#        '2 tablespoons fresh lemon juice', '2 tablespoons olive oil'],
#       dtype='object')

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {
    'analyzer': 'word',
    'ngram_range': (1,4),
    'min_df':3,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

# print('\n')
# print('-' * 80)
# print('sklearn fit transform on ingredients:', end='\n')

model_input = to_nlp_df['ingredients'].apply(" ".join).str.lower()

# print('\n')
# print('-' * 80)
# print('Input Data: ', end='\n')
# print(model_input)

# print('\n')
# print('-' * 80)
# print('Input Data Shape: ', end='\n')
# print(model_input.shape)

# print('\n')
# print('-' * 80)
# print('Random 3 Records from Input Data: ', end='\n')
# print(model_input.sample(3, random_state=200))

print("sklearn fit transform start: " + str(datetime.now()))

# Do fit transform on data
response = sklearn_transformer.fit_transform(tqdm(model_input)) 

print("sklearn fit transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)

print(transformed_recipe)
print(transformed_recipe.columns)
# Out:
# sklearn fit transform start: 2024-03-14 21:39:46.939294
# 100%|██████████| 50/50 [00:00<00:00, 9618.64it/s]
# sklearn fit transform end: 2024-03-14 21:39:46.955361
#                                 12     about  about ounces  about pound  \
# id
# 54a4270b19925f464b37c1dc  0.000000  0.000000      0.000000     0.000000
# 54a42cde19925f464b3809d2  0.000000  0.000000      0.000000     0.000000
# 54a47edf19925f464b39c58d  0.000000
# 54a419706529d92b2c006650  0.000000
# 54a4349619925f464b386b12  0.000000
# 54a4340f6529d92b2c016be8  0.006601
# 54a40e546529d92b2c004606  0.006398
# 54a428b419925f464b37d5ce  0.000000
# 54a453a519925f464b38fd16  0.000000
# 54a41cb219925f464b376d82  0.000000
# 54a431896529d92b2c014b27  0.000000
# 54a423ab19925f464b3799f2  0.003335
# 54a47c1419925f464b39bb28  0.003063
# 593ee3ba12c27b182380821f  0.000000
# 54a456366529d92b2c02235a  0.000000
# 54a452d419925f464b38f1b5  0.000000
# 54a4659b6529d92b2c026a53  0.000000
# 54a46d5d19925f464b3982d3  0.000000
# 54a4582119925f464b3927a1  0.000000
# 54a4205319925f464b377c9f  0.000000
# 54a470cc19925f464b39906b  0.000000
# 54a44f4a6529d92b2c01de45  0.000000
# 592ef494ae10ad089795ebfa  0.000000
# 54a41f016529d92b2c00757d  0.000000
# 54a436266529d92b2c01876e  0.000000
# 54a428bd19925f464b37d63e  0.000000
# 54a45a4f6529d92b2c0234d1  0.000000
# 54a41ed76529d92b2c007440  0.000000
# 54a42c906529d92b2c010b74  0.000000
# 569519a6dc18ea6c22c9b9ab  0.000000
# 54a438d56529d92b2c019648  0.000000
#
# [50 rows x 2467 columns]
# Index(['', ' ', '  ', '   ', '    ', '     ', '      ', '       ', '       ( ',
#        '       )',
#        ...
#        '-  - ', '-  -  ', '- -', '- - ', '- -  ', '- -   ', '- -    ', '- - -',
#        '- - - ', '- - -  '],
#       dtype='object', length=2467)

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {    
    'analyzer': claude_analyzer(
        stanza_pipeline=nlp,
        minNgramLength=1,
        maxNgramLength=4
        ),
    'min_df':3,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

model_input = to_nlp_df['ingredients']

# Do fit transform on data
print("fit_transform start: " + str(datetime.now()))
response = sklearn_transformer.fit_transform(tqdm(model_input)) 
print("fit_transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)
print(transformed_recipe)
print(transformed_recipe.columns)
# Out:
# fit_transform start: 2024-03-14 21:41:17.924365
#   0%|          | 0/50 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 18
#      16 # Do fit transform on data
#      17 print("fit_transform start: " + str(datetime.now()))
# ---> 18 response = sklearn_transformer.fit_transform(tqdm(model_input))
#      19 print("fit_transform end: " + str(datetime.now()))
#      21 transformed_recipe = pd.DataFrame(
#      22         response.toarray(),
#      23         columns=sklearn_transformer.get_feature_names_out(),
#      24         index=model_input.index
#      25 )
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:2139, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2132 self._check_params()
#    2133 self._tfidf = TfidfTransformer(
#    2134     norm=self.norm,
#    2135     use_idf=self.use_idf,
#    2136     smooth_idf=self.smooth_idf,
#    2137     sublinear_tf=self.sublinear_tf,
#    2138 )
# -> 2139 X = super().fit_transform(raw_documents)
#    2140 self._tfidf.fit(X)
#    2141 # X is already a transformed view of raw_documents so
#    2142 # we set copy to False
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:1389, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1381             warnings.warn(
#    1382                 "Upper case characters found in"
#    1383                 " vocabulary while 'lowercase'"
#    1384                 " is True. These entries will not"
#    1385                 " be matched with any documents"
#    1386             )
#    1387             break
# -> 1389 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1391 if self.binary:
#    1392     X.data.fill(1)
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:1276, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1274 for doc in raw_documents:
#    1275     feature_counter = {}
# -> 1276     for feature in analyze(doc):
#    1277         try:
#    1278             feature_idx = vocabulary[feature]
#
# Cell In[6], line 67, in claude_analyzer.<locals>.ngrams_per_line(word_list)
#      65 # Use itertools.islice to slice each iterator
#      66 for i, it in enumerate(iterators):
# ---> 67     iterators[i] = islice(it, i, len(terms))
#      69 # Yield n-grams of the desired length
#      70 yield from (" ".join(ngram) for ngram in zip(*iterators))
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Claude code could maybe be fixable if I can find why it's trying to reassign a tuple

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {    
    'analyzer': phind70b_analyzer(
        stanza_pipeline=nlp,
        minNgramLength=1,
        maxNgramLength=4
        ),
    'min_df':1,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

model_input = to_nlp_df['ingredients']

# Do fit transform on data
print("fit_transform start: " + str(datetime.now()))
response = sklearn_transformer.fit_transform(tqdm(model_input)) 
print("fit_transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)
print(transformed_recipe)
print(transformed_recipe.columns)
# Out:
# fit_transform start: 2024-03-14 21:41:44.316464
# 100%|██████████| 50/50 [01:25<00:00,  1.72s/it]
# fit_transform end: 2024-03-14 21:43:10.212200
#                           ( inch - long ) loaf italian bread ( inch diameter ) , cut slice , inch thick brk large garlic clove , halve crosswise brk salt brk ground black pepper brk cup extra-virgin olive oil brk ( - pound ) ball fresh , salt mozzarella brk tablespoon prepare basil pesto ( see cook 's note ) brk tablespoon mascarpone , soften brk large pit black olive ( mediterranean - style can california ) , end trim olive cut crosswise third brk ( - ounce ) jar roast red bell pepper , drain , pat dry , cut thin strip  \
# id
# 54a4270b19925f464b37c1dc                                                0.0
# 54a42cde19925f464b3809d2                                                0.0
# 54a433036529d92b2c015de3                                                0.0
# 54a451926529d92b2c01eda8                                                0.0
# 54a430876529d92b2c013e2b                                                0.0
# 54a453df6529d92b2c020687                                                0.0
# 55b0e7116284773353bf4580                                                0.0
# 54a42bab6529d92b2c00ffa7                                                0.0
# 54a4748f19925f464b399ef2                                                0.0
# 54a4356a19925f464b3875bb                                                0.0
# 54a4697e6529d92b2c0279d3                                                0.0
# 54a45e426529d92b2c02488f                                                0.0
# 54a452c96529d92b2c01f889                                                0.0
# 54a4323619925f464b384bcc                                                0.0
# 54a4259119925f464b37af9c                                                0.0
# 54a431da6529d92b2c014ee9                                                0.0
# 54a426fd19925f464b37c125                                                1.0
# 54a47bb019925f464b39b9b7                                                0.0
# 54a434d819925f464b386e62                                                0.0
# 54a428116529d92b2c00d1a7                                                0.0
# 54a436036529d92b2c01859e                                                0.0
# 54a47edf19925f464b39c58d                                                0.0
# 54a419706529d92b2c006650                                                0.0
# 54a4349619925f464b386b12                                                0.0
# 54a4340f6529d92b2c016be8                                                0.0
# 54a40e546529d92b2c004606                                                0.0
# 54a428b419925f464b37d5ce                                                0.0
# 54a453a519925f464b38fd16                                                0.0
# 54a41cb219925f464b376d82                                                0.0
# 54a431896529d92b2c014b27                                                0.0
# 54a423ab19925f464b3799f2                                                0.0
# 54a47c1419925f464b39bb28                                                0.0
# 593ee3ba12c27b182380821f                                                0.0
# 54a456366529d92b2c02235a                                                0.0
# 54a452d419925f464b38f1b5                                                0.0
# 54a4659b6529d92b2c026a53                                                0.0
# 54a46d5d19925f464b3982d3                                                0.0
# 54a4582119925f464b3927a1                                                0.0
# 54a4205319925f464b377c9f                                                0.0
# 54a470cc19925f464b39906b                                                0.0
# 54a44f4a6529d92b2c01de45                                                0.0
# 592ef494ae10ad089795ebfa                                                0.0
# 54a41f016529d92b2c00757d                                                0.0
# 54a436266529d92b2c01876e                                                0.0
# 54a430876529d92b2c013e2b                  0.000000
# 54a453df6529d92b2c020687                  0.000000
# 55b0e7116284773353bf4580                  0.000000
# 54a42bab6529d92b2c00ffa7                  0.000000
# 54a4748f19925f464b399ef2                  0.000000
# 54a4356a19925f464b3875bb                  0.000000
# 54a4697e6529d92b2c0279d3                  0.000000
# 54a45e426529d92b2c02488f                  0.000000
# 54a452c96529d92b2c01f889                  0.000000
# 54a4323619925f464b384bcc                  0.000000
# 54a4259119925f464b37af9c                  0.000000
# 54a431da6529d92b2c014ee9                  0.000000
# 54a426fd19925f464b37c125                  0.000000
# 54a47bb019925f464b39b9b7                  0.000000
# 54a434d819925f464b386e62                  0.000000
# 54a428116529d92b2c00d1a7                  0.000000
# 54a436036529d92b2c01859e                  0.000000
# 54a47edf19925f464b39c58d                  0.000000
# 54a419706529d92b2c006650                  0.000000
# 54a4349619925f464b386b12                  0.577350
# 54a4340f6529d92b2c016be8                  0.000000
# 54a40e546529d92b2c004606                  0.000000
# 54a428b419925f464b37d5ce                  0.779155
# 54a453a519925f464b38fd16                  0.000000
# 54a41cb219925f464b376d82                  0.000000
# 54a431896529d92b2c014b27                  0.000000
# 54a423ab19925f464b3799f2                  0.000000
# 54a47c1419925f464b39bb28                  0.000000
# 593ee3ba12c27b182380821f                  0.000000
# 54a456366529d92b2c02235a                  0.000000
# 54a452d419925f464b38f1b5                  0.000000
# 54a4659b6529d92b2c026a53                  0.000000
# 54a46d5d19925f464b3982d3                  0.000000
# 54a4582119925f464b3927a1                  0.000000
# 54a4205319925f464b377c9f                  0.000000
# 54a470cc19925f464b39906b                  0.000000
# 54a44f4a6529d92b2c01de45                  0.000000
# 592ef494ae10ad089795ebfa                  0.000000
# 54a41f016529d92b2c00757d                  0.000000
# 54a436266529d92b2c01876e                  0.000000
# 54a428bd19925f464b37d63e                  0.000000
# 54a45a4f6529d92b2c0234d1                  0.000000
# 54a41ed76529d92b2c007440                  0.000000
# 54a42c906529d92b2c010b74                  0.707107
# 569519a6dc18ea6c22c9b9ab                  0.000000
# 54a438d56529d92b2c019648                  0.000000
# Index(['cup chop onion', 'cup olive oil', 'cup sour cream', 'cup sugar',
#        'cup water', 'large egg', 'tablespoon extra-virgin olive oil',
#        'tablespoon fresh lemon juice', 'tablespoon olive oil',
#        'tablespoon sugar', 'tablespoon white wine vinegar',
#        'teaspoon ground cumin', 'teaspoon salt', 'teaspoon vanilla extract'],
#       dtype='object')

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {    
    'analyzer': groq_mixtral_itertools_analyzer(
        stanza_pipeline=nlp,
        minNgramLength=1,
        maxNgramLength=4
        ),
    'min_df':1,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

model_input = to_nlp_df['ingredients']

# Do fit transform on data
print("fit_transform start: " + str(datetime.now()))
response = sklearn_transformer.fit_transform(tqdm(model_input)) 
print("fit_transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)
print(transformed_recipe)
print(transformed_recipe.columns)
# Out:
# fit_transform start: 2024-03-14 21:44:39.466667
# 100%|██████████| 50/50 [01:28<00:00,  1.76s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 18
#      16 # Do fit transform on data
#      17 print("fit_transform start: " + str(datetime.now()))
# ---> 18 response = sklearn_transformer.fit_transform(tqdm(model_input))
#      19 print("fit_transform end: " + str(datetime.now()))
#      21 transformed_recipe = pd.DataFrame(
#      22         response.toarray(),
#      23         columns=sklearn_transformer.get_feature_names_out(),
#      24         index=model_input.index
#      25 )
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:2139, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2132 self._check_params()
#    2133 self._tfidf = TfidfTransformer(
#    2134     norm=self.norm,
#    2135     use_idf=self.use_idf,
#    2136     smooth_idf=self.smooth_idf,
#    2137     sublinear_tf=self.sublinear_tf,
#    2138 )
# -> 2139 X = super().fit_transform(raw_documents)
#    2140 self._tfidf.fit(X)
#    2141 # X is already a transformed view of raw_documents so
#    2142 # we set copy to False
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:1389, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1381             warnings.warn(
#    1382                 "Upper case characters found in"
#    1383                 " vocabulary while 'lowercase'"
#    1384                 " is True. These entries will not"
#    1385                 " be matched with any documents"
#    1386             )
#    1387             break
# -> 1389 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1391 if self.binary:
#    1392     X.data.fill(1)
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:1295, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1293     vocabulary = dict(vocabulary)
#    1294     if not vocabulary:
# -> 1295         raise ValueError(
#    1296             "empty vocabulary; perhaps the documents only contain stop words"
#    1297         )
#    1299 if indptr[-1] > np.iinfo(np.int32).max:  # = 2**31 - 1
#    1300     if _IS_32BIT:
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %% [markdown]
# Don't think I'm excluding stopwords in this pipeline...

# %% [markdown]
# Based on how fast the base sklearn n-gram creator is, it might just be better to do some text preprocessing and just ask sklearn to take over
#
# eg, converting all words to lemmas, then converting/created tokens from the lemmas
#
# example, spark creates n grams by taking things like "olive" and "oil" and making the bigram "olive_oil"

# %%
import nltk
def test_nltk_ngrams_per_line(ingredients_list):

    lowered = " brk ".join(
        map(str, [ingred for ingred in ingredients_list if ingred is not None])
    ).lower()

    if lowered is None:
        lowered = "Missing ingredients"

    preproc = nlp(lowered)

    lemmad = " ".join(
        map(
            str,
            [
                word.lemma
                for sent in preproc.sentences
                for word in sent.words
                if (
                    word.upos
                    not in ["NUM", "DET", "ADV", "CCONJ", "ADP", "SCONJ"]
                    and word is not None
                )
            ],
        )
    )

    split = lemmad.split(" brk ")

    yield nltk.everygrams(split, max_len=4)

# %%
print("n-gram creation start: " + str(datetime.now()))
small_input = [n_gram for n_gram in test_nltk_ngrams_per_line(model_input)]
print("n-gram creation end: " + str(datetime.now()))
# Out:
# n-gram creation start: 2024-03-14 21:47:20.593932
# n-gram creation end: 2024-03-14 21:49:00.252510

# %%
print(small_input)
# Out:
# [<generator object everygrams>]

# %%
model_input
# Out:
# id
# 54a4270b19925f464b37c1dc    [1 1/2 cups white wine vinegar, 1/2 cup sugar,...
# 54a42cde19925f464b3809d2    [3 large fresh jalapeños (4 inches), sliced 1/...
# 54a433036529d92b2c015de3    [4 cups chopped red onions (about 2 large), 1 ...
# 54a451926529d92b2c01eda8    [1 pound chicken parts, 2 stalks celery, inclu...
# 54a430876529d92b2c013e2b    [2 tablespoons olive oil, 1 cup chopped onion,...
# 54a453df6529d92b2c020687    [3/4 cup granulated sugar, 2 1/2 cups all-purp...
# 55b0e7116284773353bf4580    [1 1/2 cups packed dark brown sugar, 1 cup kos...
# 54a42bab6529d92b2c00ffa7    [Organic unsweetened cocoa powder, for dusting...
# 54a4748f19925f464b399ef2    [1/2 cup olive oil, 6 tablespoons fresh lime j...
# 54a431896529d92b2c014b27    1 pound broccoli, stems and heads cut into bit...
# 54a423ab19925f464b3799f2    1 teaspoon extra-virgin olive oil brk Juice of...
# 54a47c1419925f464b39bb28    2 cups fresh carrot juice* brk 2 tablespoons f...
# 593ee3ba12c27b182380821f    5 tablespoons olive oil, plus more for grill b...
# 54a456366529d92b2c02235a    1 teaspoon salt brk 1 teaspoon freshly ground ...
# 54a452d419925f464b38f1b5    6 small russet potatoes (about 7 ounces each),...
# 54a4659b6529d92b2c026a53    4 tablespoons olive oil brk 1 1-pound unpeeled...
# 54a46d5d19925f464b3982d3    2 12-ounce bags frozen unsweetened raspberries...
# 54a4582119925f464b3927a1    1 cup sour cream brk 6 ounces crumbled Roquefo...
# 54a4205319925f464b377c9f    1/4 cup sesame seeds brk 1 teaspoon dried red ...
# 54a470cc19925f464b39906b    3/4 cup lentils, picked over brk 1 green bell ...
# 54a44f4a6529d92b2c01de45    saké brk 3/4 cup (150 ml) mirin brk 2 cups (45...
# 592ef494ae10ad089795ebfa    15 dried chiles de árbol brk 2 dried guajillo ...
# 54a41f016529d92b2c00757d    1 pound ramps brk 1/4 cup (1/2 stick) unsalted...
# 54a436266529d92b2c01876e    2 medium beets with stems trimmed to 1 inch (1...
# 54a428bd19925f464b37d63e    8 poblano chiles brk 2 bunches green onions (a...
# 54a45a4f6529d92b2c0234d1    4 cups chilled cranberry juice cocktail brk 2 ...
# 54a41ed76529d92b2c007440    1 cup fresh lime juice brk 1/2 cup sugar brk 1...
# 54a42c906529d92b2c010b74    9 tablespoons (1 stick plus 1 tablespoon) unsa...
# 569519a6dc18ea6c22c9b9ab      2 cups Japanese short-grain white or haiga rice
# 54a438d56529d92b2c019648    1/4 cup red wine vinegar brk 3 tablespoons min...
# Name: ingredients, dtype: object

# %%
joined_with_brk[joined_with_brk.isnull()]
# Out:
# Series([], Name: ingredients, dtype: object)

# %%
stanzad = nlp(joined_with_brk.tolist())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 stanzad = nlp(joined_with_brk.tolist())
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/stanza/pipeline/core.py:471, in Pipeline.__call__(self, doc, processors)
#     470 def __call__(self, doc, processors=None):
# --> 471     return self.process(doc, processors)
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/stanza/pipeline/core.py:422, in Pipeline.process(self, doc, processors)
#     420     if self.processors.get(processor_name):
#     421         process = self.processors[processor_name].bulk_process if bulk else self.processors[processor_name].process
# --> 422         doc = process(doc)
#     423 return doc
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/stanza/pipeline/tokenize_processor.py:80, in TokenizeProcessor.process(self, document)
#      78 def process(self, document):
#      79     if not (isinstance(document, str) or isinstance(document, doc.Document) or (self.config.get('pretokenized') or self.config.get('no_ssplit', False))):
# ---> 80         raise ValueError("If neither 'pretokenized' or 'no_ssplit' option is enabled, the input to the TokenizerProcessor must be a string or a Document object.  Got %s" % str(type(document)))
#      82     if isinstance(document, doc.Document):
#      83         if self.config.get('pretokenized'):
#
# ValueError: If neither 'pretokenized' or 'no_ssplit' option is enabled, the input to the TokenizerProcessor must be a string or a Document object.  Got <class 'list'>

# %%
print([_ for _ in map(nlp, joined_with_brk)])
# Out:
# [[
#   [
#     {
#       "id": 1,
#       "text": "1",
#       "lemma": "1",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 3,
#       "deprel": "nummod",
#       "start_char": 0,
#       "end_char": 1,
#       "ner": "B-CARDINAL",
#       "multi_ner": [
#         "B-CARDINAL"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "1/2",
#       "lemma": "1/2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 1,
#       "deprel": "compound",
#       "start_char": 2,
#       "end_char": 5,
#       "ner": "E-CARDINAL",
#       "multi_ner": [
#         "E-CARDINAL"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "cups",
#       "lemma": "cup",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 15,
#       "deprel": "nmod:npmod",
#       "start_char": 6,
#       "end_char": 10,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "white",
#       "lemma": "white",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 6,
#       "deprel": "amod",
#       "start_char": 11,
#       "end_char": 16,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "wine",
#       "lemma": "wine",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "compound",
#       "start_char": 17,
#       "end_char": 21,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "vinegar",
#       "lemma": "vinegar",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 15,
#       "deprel": "compound",
#       "start_char": 22,
#       "end_char": 29,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "compound",
#       "start_char": 30,
#       "end_char": 33,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "1/2",
#       "lemma": "1/2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 9,
#       "deprel": "nummod",
#       "start_char": 34,
#       "end_char": 37,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "cup",
#       "lemma": "cup",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 10,
#       "deprel": "compound",
#       "start_char": 38,
#       "end_char": 41,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "sugar",
#       "lemma": "sugar",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 15,
#       "deprel": "compound",
#       "start_char": 42,
#       "end_char": 47,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 13,
#       "deprel": "compound",
#       "start_char": 48,
#       "end_char": 51,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "1/2",
#       "lemma": "1/2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 13,
#       "deprel": "nummod",
#       "start_char": 52,
#       "end_char": 55,
#       "ner": "S-CARDINAL",
#       "multi_ner": [
#         "S-CARDINAL"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "cup",
#       "lemma": "cup",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 15,
#       "deprel": "compound",
#       "start_char": 56,
#       "end_char": 59,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "water",
#       "lemma": "water",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 15,
#       "deprel": "compound",
#       "start_char": 60,
#       "end_char": 65,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 66,
#       "end_char": 69,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "3",
#       "lemma": "3",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 15,
#       "deprel": "nummod",
#       "start_char": 70,
#       "end_char": 71,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ],
#   [
#     {
#       "id": 1,
#       "text": "Turkish",
#       "lemma": "Turkish",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 2,
#       "deprel": "amod",
#       "start_char": 72,
#       "end_char": 79,
#       "ner": "S-NORP",
#       "multi_ner": [
#         "S-NORP"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "bay",
#       "lemma": "bay",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "nsubj",
#       "start_char": 80,
#       "end_char": 83,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "leaves",
#       "lemma": "leave",
#       "upos": "VERB",
#       "xpos": "VBZ",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 84,
#       "end_char": 90,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 6,
#       "deprel": "compound",
#       "start_char": 91,
#       "end_char": 94,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "1/2",
#       "lemma": "1/2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 6,
#       "deprel": "nummod",
#       "start_char": 95,
#       "end_char": 98,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "teaspoon",
#       "lemma": "teaspoon",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 7,
#       "deprel": "obl:npmod",
#       "start_char": 99,
#       "end_char": 107,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "dried",
#       "lemma": "dry",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 14,
#       "deprel": "amod",
#       "start_char": 108,
#       "end_char": 113,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "crushed",
#       "lemma": "crush",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 14,
#       "deprel": "amod",
#       "start_char": 114,
#       "end_char": 121,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "red",
#       "lemma": "red",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 10,
#       "deprel": "amod",
#       "start_char": 122,
#       "end_char": 125,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "pepper",
#       "lemma": "pepper",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 14,
#       "deprel": "compound",
#       "start_char": 126,
#       "end_char": 132,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 14,
#       "deprel": "compound",
#       "start_char": 133,
#       "end_char": 136,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "Coarse",
#       "lemma": "Coarse",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 14,
#       "deprel": "amod",
#       "start_char": 137,
#       "end_char": 143,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "kosher",
#       "lemma": "kosher",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 14,
#       "deprel": "compound",
#       "start_char": 144,
#       "end_char": 150,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "salt",
#       "lemma": "salt",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 15,
#       "deprel": "compound",
#       "start_char": 151,
#       "end_char": 155,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "obj",
#       "start_char": 156,
#       "end_char": 159,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "1",
#       "lemma": "1",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 20,
#       "deprel": "nummod",
#       "start_char": 160,
#       "end_char": 161,
#       "ner": "S-CARDINAL",
#       "multi_ner": [
#         "S-CARDINAL"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "to",
#       "lemma": "to",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 18,
#       "deprel": "case",
#       "start_char": 162,
#       "end_char": 164,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "1",
#       "lemma": "1",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 16,
#       "deprel": "nmod",
#       "start_char": 165,
#       "end_char": 166,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "1/4",
#       "lemma": "1/4",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 20,
#       "deprel": "nummod",
#       "start_char": 167,
#       "end_char": 170,
#       "ner": "I-QUANTITY",
#       "multi_ner": [
#         "I-QUANTITY"
#       ]
#     },
#     {
#       "id": 20,
#       "text": "pounds",
#       "lemma": "pound",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 22,
#       "deprel": "nmod:npmod",
#       "start_char": 171,
#       "end_char": 177,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 21,
#       "text": "red",
#       "lemma": "red",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 22,
#       "deprel": "amod",
#       "start_char": 178,
#       "end_char": 181,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 22,
#       "text": "onions",
#       "lemma": "onion",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 15,
#       "deprel": "conj",
#       "start_char": 182,
#       "end_char": 188,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 23,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 3,
#       "deprel": "punct",
#       "start_char": 188,
#       "end_char": 189,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 24,
#       "text": "thinly",
#       "lemma": "thinly",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 25,
#       "deprel": "advmod",
#       "start_char": 190,
#       "end_char": 196,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 25,
#       "text": "sliced",
#       "lemma": "slice",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 28,
#       "deprel": "amod",
#       "start_char": 197,
#       "end_char": 203,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 26,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 28,
#       "deprel": "compound",
#       "start_char": 204,
#       "end_char": 207,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 27,
#       "text": "1/4",
#       "lemma": "1/4",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 28,
#       "deprel": "nummod",
#       "start_char": 208,
#       "end_char": 211,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 28,
#       "text": "cup",
#       "lemma": "cup",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 31,
#       "deprel": "nmod:npmod",
#       "start_char": 212,
#       "end_char": 215,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 29,
#       "text": "white",
#       "lemma": "white",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 31,
#       "deprel": "amod",
#       "start_char": 216,
#       "end_char": 221,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 30,
#       "text": "wine",
#       "lemma": "wine",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 31,
#       "deprel": "compound",
#       "start_char": 222,
#       "end_char": 226,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 31,
#       "text": "vinegar",
#       "lemma": "vinegar",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "parataxis",
#       "start_char": 227,
#       "end_char": 234,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 32,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 34,
#       "deprel": "compound",
#       "start_char": 235,
#       "end_char": 238,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 33,
#       "text": "1/2",
#       "lemma": "1/2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 34,
#       "deprel": "nummod",
#       "start_char": 239,
#       "end_char": 242,
#       "ner": "S-CARDINAL",
#       "multi_ner": [
#         "S-CARDINAL"
#       ]
#     },
#     {
#       "id": 34,
#       "text": "teaspoon",
#       "lemma": "teaspoon",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 36,
#       "deprel": "nmod:npmod",
#       "start_char": 243,
#       "end_char": 251,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 35,
#       "text": "Dijon",
#       "lemma": "Dijon",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 36,
#       "deprel": "compound",
#       "start_char": 252,
#       "end_char": 257,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 36,
#       "text": "mustard",
#       "lemma": "mustard",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 41,
#       "deprel": "compound",
#       "start_char": 258,
#       "end_char": 265,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 37,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 41,
#       "deprel": "compound",
#       "start_char": 266,
#       "end_char": 269,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 38,
#       "text": "1/2",
#       "lemma": "1/2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 39,
#       "deprel": "nummod",
#       "start_char": 270,
#       "end_char": 273,
#       "ner": "S-CARDINAL",
#       "multi_ner": [
#         "S-CARDINAL"
#       ]
#     },
#     {
#       "id": 39,
#       "text": "cup",
#       "lemma": "cup",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 41,
#       "deprel": "compound",
#       "start_char": 274,
#       "end_char": 277,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 40,
#       "text": "olive",
#       "lemma": "olive",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 41,
#       "deprel": "compound",
#       "start_char": 278,
#       "end_char": 283,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 41,
#       "text": "oil",
#       "lemma": "oil",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "parataxis",
#       "start_char": 284,
#       "end_char": 287,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 42,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 44,
#       "deprel": "compound",
#       "start_char": 288,
#       "end_char": 291,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 43,
#       "text": "1/2",
#       "lemma": "1/2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 44,
#       "deprel": "nummod",
#       "start_char": 292,
#       "end_char": 295,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 44,
#       "text": "cup",
#       "lemma": "cup",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 47,
#       "deprel": "nmod:npmod",
#       "start_char": 296,
#       "end_char": 299,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 45,
#       "text": "crumbled",
#       "lemma": "crumble",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 47,
#       "deprel": "amod",
#       "start_char": 300,
#       "end_char": 308,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 46,
#       "text": "blue",
#       "lemma": "blue",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 47,
#       "deprel": "amod",
#       "start_char": 309,
#       "end_char": 313,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 47,
#       "text": "cheese",
#       "lemma": "cheese",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "parataxis",
#       "start_char": 314,
#       "end_char": 320,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 48,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 47,
#       "deprel": "appos",
#       "start_char": 321,
#       "end_char": 324,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 49,
#       "text": "4",
#       "lemma": "4",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 50,
#       "deprel": "nummod",
#       "start_char": 325,
#       "end_char": 326,
#       "ner": "S-CARDINAL",
#       "multi_ner": [
#         "S-CARDINAL"
#       ]
#     },
#     {
#       "id": 50,
#       "text": "hearts",
#       "lemma": "heart",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 48,
#       "deprel": "conj",
#       "start_char": 327,
#       "end_char": 333,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 51,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 52,
#       "deprel": "case",
#       "start_char": 334,
#       "end_char": 336,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 52,
#       "text": "romaine",
#       "lemma": "romaine",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 50,
#       "deprel": "nmod",
#       "start_char": 337,
#       "end_char": 344,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 53,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 59,
#       "deprel": "punct",
#       "start_char": 344,
#       "end_char": 345,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 54,
#       "text": "each",
#       "lemma": "each",
#       "upos": "DET",
#       "xpos": "DT",
#       "head": 59,
#       "deprel": "det",
#       "start_char": 346,
#       "end_char": 350,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 55,
#       "text": "quartered",
#       "lemma": "quarter",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 59,
#       "deprel": "amod",
#       "start_char": 351,
#       "end_char": 360,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 56,
#       "text": "lengthwise",
#       "lemma": "lengthwise",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 59,
#       "deprel": "compound",
#       "start_char": 361,
#       "end_char": 371,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 57,
#       "text": "Crumbled",
#       "lemma": "crumble",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 59,
#       "deprel": "amod",
#       "start_char": 372,
#       "end_char": 380,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 58,
#       "text": "blue",
#       "lemma": "blue",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 59,
#       "deprel": "amod",
#       "start_char": 381,
#       "end_char": 385,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 59,
#       "text": "cheese",
#       "lemma": "cheese",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 48,
#       "deprel": "conj",
#       "start_char": 386,
#       "end_char": 392,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 60,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "head": 62,
#       "deprel": "punct",
#       "start_char": 393,
#       "end_char": 394,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 61,
#       "text": "for",
#       "lemma": "for",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 62,
#       "deprel": "case",
#       "start_char": 394,
#       "end_char": 397,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 62,
#       "text": "garnish",
#       "lemma": "garnish",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 59,
#       "deprel": "nmod",
#       "start_char": 398,
#       "end_char": 405,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 63,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "head": 62,
#       "deprel": "punct",
#       "start_char": 405,
#       "end_char": 406,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ]
# ], [
#   [
#     {
#       "id": 1,
#       "text": "3",
#       "lemma": "3",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 4,
#       "deprel": "nummod",
#       "start_char": 0,
#       "end_char": 1,
#       "ner": "S-CARDINAL",
#       "multi_ner": [
#         "S-CARDINAL"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "large",
#       "lemma": "large",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 4,
#       "deprel": "amod",
#       "start_char": 2,
#       "end_char": 7,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "fresh",
#       "lemma": "fresh",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 4,
#       "deprel": "amod",
#       "start_char": 8,
#       "end_char": 13,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "jalapeños",
#       "lemma": "jalapeño",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 36,
#       "deprel": "nsubj",
#       "start_char": 14,
#       "end_char": 23,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "head": 7,
#       "deprel": "punct",
#       "start_char": 24,
#       "end_char": 25,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "4",
#       "lemma": "4",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 7,
#       "deprel": "nummod",
#       "start_char": 25,
#       "end_char": 26,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "inches",
#       "lemma": "inch",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 4,
#       "deprel": "appos",
#       "start_char": 27,
#       "end_char": 33,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 8,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "head": 7,
#       "deprel": "punct",
#       "start_char": 33,
#       "end_char": 34,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 4,
#       "deprel": "punct",
#       "start_char": 34,
#       "end_char": 35,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "sliced",
#       "lemma": "slice",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 4,
#       "deprel": "acl",
#       "start_char": 36,
#       "end_char": 42,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "1/8",
#       "lemma": "1/8",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 12,
#       "deprel": "nummod",
#       "start_char": 43,
#       "end_char": 46,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "inch",
#       "lemma": "inch",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 13,
#       "deprel": "obl:npmod",
#       "start_char": 47,
#       "end_char": 51,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "thick",
#       "lemma": "thick",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 19,
#       "deprel": "amod",
#       "start_char": 52,
#       "end_char": 57,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 19,
#       "deprel": "compound",
#       "start_char": 58,
#       "end_char": 61,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "1/",
#       "lemma": "1/",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 17,
#       "deprel": "nummod",
#       "start_char": 62,
#       "end_char": 64,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "2",
#       "lemma": "2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 17,
#       "deprel": "nummod",
#       "start_char": 64,
#       "end_char": 65,
#       "ner": "I-QUANTITY",
#       "multi_ner": [
#         "I-QUANTITY"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "cup",
#       "lemma": "cup",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 19,
#       "deprel": "compound",
#       "start_char": 66,
#       "end_char": 69,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "soy",
#       "lemma": "soy",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 19,
#       "deprel": "compound",
#       "start_char": 70,
#       "end_char": 73,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "sauce",
#       "lemma": "sauce",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 4,
#       "deprel": "conj",
#       "start_char": 74,
#       "end_char": 79,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 20,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 22,
#       "deprel": "compound",
#       "start_char": 80,
#       "end_char": 83,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 21,
#       "text": "1/2",
#       "lemma": "1/2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 22,
#       "deprel": "nummod",
#       "start_char": 84,
#       "end_char": 87,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 22,
#       "text": "cup",
#       "lemma": "cup",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 24,
#       "deprel": "compound",
#       "start_char": 88,
#       "end_char": 91,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 23,
#       "text": "water",
#       "lemma": "water",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 24,
#       "deprel": "compound",
#       "start_char": 92,
#       "end_char": 97,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 24,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 30,
#       "deprel": "nsubj",
#       "start_char": 98,
#       "end_char": 101,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 25,
#       "text": "2",
#       "lemma": "2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 26,
#       "deprel": "nummod",
#       "start_char": 102,
#       "end_char": 103,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 26,
#       "text": "teaspoons",
#       "lemma": "teaspoon",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 29,
#       "deprel": "nmod:npmod",
#       "start_char": 104,
#       "end_char": 113,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 27,
#       "text": "grated",
#       "lemma": "grate",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 29,
#       "deprel": "amod",
#       "start_char": 114,
#       "end_char": 120,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 28,
#       "text": "lemon",
#       "lemma": "lemon",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 29,
#       "deprel": "compound",
#       "start_char": 121,
#       "end_char": 126,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 29,
#       "text": "zest",
#       "lemma": "zest",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 30,
#       "deprel": "compound",
#       "start_char": 127,
#       "end_char": 131,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 30,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 132,
#       "end_char": 135,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 31,
#       "text": "2",
#       "lemma": "2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 32,
#       "deprel": "nummod",
#       "start_char": 136,
#       "end_char": 137,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 32,
#       "text": "teaspoons",
#       "lemma": "teaspoon",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 36,
#       "deprel": "nmod:npmod",
#       "start_char": 138,
#       "end_char": 147,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 33,
#       "text": "packed",
#       "lemma": "pack",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 36,
#       "deprel": "amod",
#       "start_char": 148,
#       "end_char": 154,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 34,
#       "text": "dark",
#       "lemma": "dark",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 36,
#       "deprel": "amod",
#       "start_char": 155,
#       "end_char": 159,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 35,
#       "text": "brown",
#       "lemma": "brown",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 36,
#       "deprel": "amod",
#       "start_char": 160,
#       "end_char": 165,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 36,
#       "text": "sugar",
#       "lemma": "sugar",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 30,
#       "deprel": "conj",
#       "start_char": 166,
#       "end_char": 171,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ]
# ], [
#   [
#     {
#       "id": 1,
#       "text": "4",
#       "lemma": "4",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 2,
#       "deprel": "nummod",
#       "start_char": 0,
#       "end_char": 1,
#       "ner": "S-CARDINAL",
#       "multi_ner": [
#         "S-CARDINAL"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "cups",
#       "lemma": "cup",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 3,
#       "deprel": "obj",
#       "start_char": 2,
#       "end_char": 6,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "chopped",
#       "lemma": "chop",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 5,
#       "deprel": "amod",
#       "start_char": 7,
#       "end_char": 14,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "red",
#       "lemma": "red",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 5,
#       "deprel": "amod",
#       "start_char": 15,
#       "end_char": 18,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "onions",
#       "lemma": "onion",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 16,
#       "deprel": "nsubj",
#       "start_char": 19,
#       "end_char": 25,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "head": 9,
#       "deprel": "punct",
#       "start_char": 26,
#       "end_char": 27,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "about",
#       "lemma": "about",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 8,
#       "deprel": "advmod",
#       "start_char": 27,
#       "end_char": 32,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "2",
#       "lemma": "2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 9,
#       "deprel": "nummod",
#       "start_char": 33,
#       "end_char": 34,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "large",
#       "lemma": "large",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 5,
#       "deprel": "parataxis",
#       "start_char": 35,
#       "end_char": 40,
#       "ner": "I-QUANTITY",
#       "multi_ner": [
#         "I-QUANTITY"
#       ]
#     },
#     {
#       "id": 10,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "head": 9,
#       "deprel": "punct",
#       "start_char": 40,
#       "end_char": 41,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 16,
#       "deprel": "compound",
#       "start_char": 42,
#       "end_char": 45,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "1",
#       "lemma": "1",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 14,
#       "deprel": "nummod",
#       "start_char": 46,
#       "end_char": 47,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "1/2",
#       "lemma": "1/2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 14,
#       "deprel": "nummod",
#       "start_char": 48,
#       "end_char": 51,
#       "ner": "I-QUANTITY",
#       "multi_ner": [
#         "I-QUANTITY"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "tablespoons",
#       "lemma": "tablespoon",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 16,
#       "deprel": "compound",
#       "start_char": 52,
#       "end_char": 63,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 15,
#       "text": "sunflower",
#       "lemma": "sunflower",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 16,
#       "deprel": "compound",
#       "start_char": 64,
#       "end_char": 73,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "oil",
#       "lemma": "oil",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 74,
#       "end_char": 77,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "or",
#       "lemma": "or",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 19,
#       "deprel": "cc",
#       "start_char": 78,
#       "end_char": 80,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "canola",
#       "lemma": "canola",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 19,
#       "deprel": "compound",
#       "start_char": 81,
#       "end_char": 87,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "oil",
#       "lemma": "oil",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 16,
#       "deprel": "conj",
#       "start_char": 88,
#       "end_char": 91,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 20,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 24,
#       "deprel": "compound",
#       "start_char": 92,
#       "end_char": 95,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 21,
#       "text": "1",
#       "lemma": "1",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 22,
#       "deprel": "nummod",
#       "start_char": 96,
#       "end_char": 97,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 22,
#       "text": "teaspoon",
#       "lemma": "teaspoon",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 24,
#       "deprel": "compound",
#       "start_char": 98,
#       "end_char": 106,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 23,
#       "text": "nigella",
#       "lemma": "nigella",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 24,
#       "deprel": "compound",
#       "start_char": 107,
#       "end_char": 114,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 24,
#       "text": "seeds",
#       "lemma": "seed",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 16,
#       "deprel": "conj",
#       "start_char": 115,
#       "end_char": 120,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 25,
#       "text": "*",
#       "lemma": "*",
#       "upos": "PUNCT",
#       "xpos": "NFP",
#       "head": 16,
#       "deprel": "punct",
#       "start_char": 120,
#       "end_char": 121,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 26,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 28,
#       "deprel": "compound",
#       "start_char": 122,
#       "end_char": 125,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 27,
#       "text": "1",
#       "lemma": "1",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 28,
#       "deprel": "nummod",
#       "start_char": 126,
#       "end_char": 127,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 28,
#       "text": "teaspoon",
#       "lemma": "teaspoon",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 31,
#       "deprel": "nmod:npmod",
#       "start_char": 128,
#       "end_char": 136,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 29,
#       "text": "black",
#       "lemma": "black",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 31,
#       "deprel": "amod",
#       "start_char": 137,
#       "end_char": 142,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 30,
#       "text": "mustard",
#       "lemma": "mustard",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 31,
#       "deprel": "compound",
#       "start_char": 143,
#       "end_char": 150,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 31,
#       "text": "seeds",
#       "lemma": "seed",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 16,
#       "deprel": "conj",
#       "start_char": 151,
#       "end_char": 156,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 32,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 37,
#       "deprel": "compound",
#       "start_char": 157,
#       "end_char": 160,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 33,
#       "text": "1",
#       "lemma": "1",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 34,
#       "deprel": "nummod",
#       "start_char": 161,
#       "end_char": 162,
#       "ner": "S-CARDINAL",
#       "multi_ner": [
#         "S-CARDINAL"
#       ]
#     },
#     {
#       "id": 34,
#       "text": "teaspoon",
#       "lemma": "teaspoon",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 37,
#       "deprel": "nmod:npmod",
#       "start_char": 163,
#       "end_char": 171,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 35,
#       "text": "yellow",
#       "lemma": "yellow",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 37,
#       "deprel": "amod",
#       "start_char": 172,
#       "end_char": 178,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 36,
#       "text": "mustard",
#       "lemma": "mustard",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 37,
#       "deprel": "compound",
#       "start_char": 179,
#       "end_char": 186,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 37,
#       "text": "seeds",
#       "lemma": "seed",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 31,
#       "deprel": "conj",
#       "start_char": 187,
#       "end_char": 192,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 38,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 37,
#       "deprel": "parataxis",
#       "start_char": 193,
#       "end_char": 196,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 39,
#       "text": "2",
#       "lemma": "2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 40,
#       "deprel": "nummod",
#       "start_char": 197,
#       "end_char": 198,
#       "ner": "S-CARDINAL",
#       "multi_ner": [
#         "S-CARDINAL"
#       ]
#     },
#     {
#       "id": 40,
#       "text": "tablespoons",
#       "lemma": "tablespoon",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 37,
#       "deprel": "conj",
#       "start_char": 199,
#       "end_char": 210,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 41,
#       "text": "fresh",
#       "lemma": "fresh",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 43,
#       "deprel": "amod",
#       "start_char": 211,
#       "end_char": 216,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 42,
#       "text": "lemon",
#       "lemma": "lemon",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 43,
#       "deprel": "compound",
#       "start_char": 217,
#       "end_char": 222,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 43,
#       "text": "juice",
#       "lemma": "juice",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 44,
#       "deprel": "conj",
#       "start_char": 223,
#       "end_char": 228,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 44,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 37,
#       "deprel": "conj",
#       "start_char": 229,
#       "end_char": 232,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 45,
#       "text": "2",
#       "lemma": "2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
# ...
#       "start_char": 251,
#       "end_char": 252,
#       "ner": "I-QUANTITY",
#       "multi_ner": [
#         "I-QUANTITY"
#       ]
#     },
#     {
#       "id": 50,
#       "text": "thick",
#       "lemma": "thick",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 51,
#       "deprel": "amod",
#       "start_char": 252,
#       "end_char": 257,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 51,
#       "text": "rounds",
#       "lemma": "round",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 42,
#       "deprel": "obl",
#       "start_char": 258,
#       "end_char": 264,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 52,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 59,
#       "deprel": "compound",
#       "start_char": 265,
#       "end_char": 268,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 53,
#       "text": "1",
#       "lemma": "1",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 56,
#       "deprel": "nummod",
#       "start_char": 269,
#       "end_char": 270,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 54,
#       "text": "12",
#       "lemma": "12",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 56,
#       "deprel": "nummod",
#       "start_char": 271,
#       "end_char": 273,
#       "ner": "I-QUANTITY",
#       "multi_ner": [
#         "I-QUANTITY"
#       ]
#     },
#     {
#       "id": 55,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "head": 56,
#       "deprel": "punct",
#       "start_char": 273,
#       "end_char": 274,
#       "ner": "I-QUANTITY",
#       "multi_ner": [
#         "I-QUANTITY"
#       ]
#     },
#     {
#       "id": 56,
#       "text": "ounce",
#       "lemma": "ounce",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 59,
#       "deprel": "compound",
#       "start_char": 274,
#       "end_char": 279,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 57,
#       "text": "container",
#       "lemma": "container",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 59,
#       "deprel": "compound",
#       "start_char": 280,
#       "end_char": 289,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 58,
#       "text": "cherry",
#       "lemma": "cherry",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 59,
#       "deprel": "compound",
#       "start_char": 290,
#       "end_char": 296,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 59,
#       "text": "tomatoes",
#       "lemma": "tomato",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 51,
#       "deprel": "conj",
#       "start_char": 297,
#       "end_char": 305,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 60,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 62,
#       "deprel": "punct",
#       "start_char": 305,
#       "end_char": 306,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 61,
#       "text": "halved",
#       "lemma": "halve",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 62,
#       "deprel": "amod",
#       "start_char": 307,
#       "end_char": 313,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 62,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 59,
#       "deprel": "conj",
#       "start_char": 314,
#       "end_char": 317,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 63,
#       "text": "1",
#       "lemma": "1",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 62,
#       "deprel": "dep",
#       "start_char": 318,
#       "end_char": 319,
#       "ner": "B-QUANTITY",
#       "multi_ner": [
#         "B-QUANTITY"
#       ]
#     },
#     {
#       "id": 64,
#       "text": "5",
#       "lemma": "5",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 66,
#       "deprel": "nummod",
#       "start_char": 320,
#       "end_char": 321,
#       "ner": "I-QUANTITY",
#       "multi_ner": [
#         "I-QUANTITY"
#       ]
#     },
#     {
#       "id": 65,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "head": 66,
#       "deprel": "punct",
#       "start_char": 321,
#       "end_char": 322,
#       "ner": "I-QUANTITY",
#       "multi_ner": [
#         "I-QUANTITY"
#       ]
#     },
#     {
#       "id": 66,
#       "text": "ounce",
#       "lemma": "ounce",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 67,
#       "deprel": "compound",
#       "start_char": 322,
#       "end_char": 327,
#       "ner": "E-QUANTITY",
#       "multi_ner": [
#         "E-QUANTITY"
#       ]
#     },
#     {
#       "id": 67,
#       "text": "package",
#       "lemma": "package",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 70,
#       "deprel": "compound",
#       "start_char": 328,
#       "end_char": 335,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 68,
#       "text": "baby",
#       "lemma": "baby",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 70,
#       "deprel": "compound",
#       "start_char": 336,
#       "end_char": 340,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 69,
#       "text": "arugula",
#       "lemma": "arugula",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 70,
#       "deprel": "compound",
#       "start_char": 341,
#       "end_char": 348,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 70,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 62,
#       "deprel": "appos",
#       "start_char": 349,
#       "end_char": 352,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 71,
#       "text": "2",
#       "lemma": "2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 72,
#       "deprel": "nummod",
#       "start_char": 353,
#       "end_char": 354,
#       "ner": "S-CARDINAL",
#       "multi_ner": [
#         "S-CARDINAL"
#       ]
#     },
#     {
#       "id": 72,
#       "text": "cups",
#       "lemma": "cup",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 70,
#       "deprel": "conj",
#       "start_char": 355,
#       "end_char": 359,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 73,
#       "text": "(",
#       "lemma": "(",
#       "upos": "PUNCT",
#       "xpos": "-LRB-",
#       "head": 74,
#       "deprel": "punct",
#       "start_char": 360,
#       "end_char": 361,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 74,
#       "text": "packed",
#       "lemma": "pack",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 72,
#       "deprel": "appos",
#       "start_char": 361,
#       "end_char": 367,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 75,
#       "text": ")",
#       "lemma": ")",
#       "upos": "PUNCT",
#       "xpos": "-RRB-",
#       "head": 74,
#       "deprel": "punct",
#       "start_char": 367,
#       "end_char": 368,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 76,
#       "text": "torn",
#       "lemma": "tear",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 79,
#       "deprel": "amod",
#       "start_char": 369,
#       "end_char": 373,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 77,
#       "text": "fresh",
#       "lemma": "fresh",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 79,
#       "deprel": "amod",
#       "start_char": 374,
#       "end_char": 379,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 78,
#       "text": "basil",
#       "lemma": "basil",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 79,
#       "deprel": "compound",
#       "start_char": 380,
#       "end_char": 385,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 79,
#       "text": "leaves",
#       "lemma": "leave",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 70,
#       "deprel": "conj",
#       "start_char": 386,
#       "end_char": 392,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 80,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 84,
#       "deprel": "compound",
#       "start_char": 393,
#       "end_char": 396,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 81,
#       "text": "1/2",
#       "lemma": "1/2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 80,
#       "deprel": "nummod",
#       "start_char": 397,
#       "end_char": 400,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 82,
#       "text": "English",
#       "lemma": "English",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 84,
#       "deprel": "amod",
#       "start_char": 401,
#       "end_char": 408,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 83,
#       "text": "hothouse",
#       "lemma": "hothouse",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 84,
#       "deprel": "compound",
#       "start_char": 409,
#       "end_char": 417,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 84,
#       "text": "cucumber",
#       "lemma": "cucumber",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 79,
#       "deprel": "appos",
#       "start_char": 418,
#       "end_char": 426,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 85,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 86,
#       "deprel": "punct",
#       "start_char": 426,
#       "end_char": 427,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 86,
#       "text": "halved",
#       "lemma": "halve",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#       "head": 10,
#       "deprel": "parataxis",
#       "start_char": 428,
#       "end_char": 434,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 87,
#       "text": "lengthwise",
#       "lemma": "lengthwise",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 86,
#       "deprel": "advmod",
#       "start_char": 435,
#       "end_char": 445,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 88,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 100,
#       "deprel": "punct",
#       "start_char": 445,
#       "end_char": 446,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 89,
#       "text": "then",
#       "lemma": "then",
#       "upos": "ADV",
#       "xpos": "RB",
#       "feats": "PronType=Dem",
#       "head": 100,
#       "deprel": "advmod",
#       "start_char": 447,
#       "end_char": 451,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 90,
#       "text": "thinly",
#       "lemma": "thinly",
#       "upos": "ADV",
#       "xpos": "RB",
#       "head": 91,
#       "deprel": "advmod",
#       "start_char": 452,
#       "end_char": 458,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 91,
#       "text": "sliced",
#       "lemma": "slice",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 92,
#       "deprel": "amod",
#       "start_char": 459,
#       "end_char": 465,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 92,
#       "text": "crosswise",
#       "lemma": "crosswise",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 100,
#       "deprel": "compound",
#       "start_char": 466,
#       "end_char": 475,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 93,
#       "text": "brk",
#       "lemma": "brk",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 95,
#       "deprel": "compound",
#       "start_char": 476,
#       "end_char": 479,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 94,
#       "text": "1/2",
#       "lemma": "1/2",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Word|NumType=Card",
#       "head": 95,
#       "deprel": "nummod",
#       "start_char": 480,
#       "end_char": 483,
#       "ner": "S-CARDINAL",
#       "multi_ner": [
#         "S-CARDINAL"
#       ]
#     },
#     {
#       "id": 95,
#       "text": "cup",
#       "lemma": "cup",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 100,
#       "deprel": "nmod:npmod",
#       "start_char": 484,
#       "end_char": 487,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 96,
#       "text": "oil",
#       "lemma": "oil",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 98,
#       "deprel": "compound",
#       "start_char": 488,
#       "end_char": 491,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 97,
#       "text": "-",
#       "lemma": "-",
#       "upos": "PUNCT",
#       "xpos": "HYPH",
#       "head": 98,
#       "deprel": "punct",
#       "start_char": 491,
#       "end_char": 492,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 98,
#       "text": "cured",
#       "lemma": "cure",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Part",
#       "head": 100,
#       "deprel": "amod",
#       "start_char": 492,
#       "end_char": 497,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 99,
#       "text": "black",
#       "lemma": "black",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 100,
#       "deprel": "amod",
#       "start_char": 498,
#       "end_char": 503,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 100,
#       "text": "olives",
#       "lemma": "olive",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 86,
#       "deprel": "parataxis",
#       "start_char": 504,
#       "end_char": 510,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 101,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 102,
#       "deprel": "punct",
#       "start_char": 510,
#       "end_char": 511,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 102,
#       "text": "pitted",
#       "lemma": "pit",
#       "upos": "VERB",
#       "xpos": "VBN",
#       "feats": "Tense=Past|VerbForm=Fin",
#       "head": 100,
#       "deprel": "acl",
#       "start_char": 512,
#       "end_char": 518,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ]
# ]]

# %% [markdown]
# 1. There is a normalize function that is performant on pandas dataframes, just call pandas.Series.str.normalize()
# 2. Can also lowercase with pandas.Series.str.lower()
# Combined with str.join and str.split, may be able to speed things up for text pre processing
#
# However, need to write a custom function that I can use either map or apply with. This custome function can do the Stanza lemmatization

# %%
test_transforms = model_input.str.join(" brk ").str.normalize('NFKC').str.lower().fillna("Missing ingredients")

# %%
stanza_pipelined = nlp(test_transforms[0])

# %%
def mini_stanza_function(row, stanza_pipeline):
    lemmafied = " ".join(str(word.lemma) 
                         for sent in stanza_pipeline(row).sentences
                         for word in sent.words
                         if (word.upos 
                             not in ["NUM", 
                                     "DET", 
                                     "ADV", 
                                     "CCONJ", 
                                     "ADP", 
                                     "SCONJ",
                                     "PUNCT"
                                     ]
                            and word is not None
                            )
                        )
    return lemmafied

# %%
mini_stanza_function(test_transforms[0], nlp)
# Out:
# 'cup white wine vinegar brk cup sugar brk cup water brk turkish bay leave brk teaspoon dry crush red pepper brk coarse kosher salt brk pound red onion slice brk cup white wine vinegar brk teaspoon dijon mustard brk cup olive oil brk cup crumble blue cheese brk heart romaine quarter lengthwise crumble blue cheese garnish'

# %%
lemmafied = test_transforms.apply(lambda x: mini_stanza_function(x, nlp))

# %%
lemmafied
# Out:
# id
# 54a4270b19925f464b37c1dc    cup white wine vinegar brk cup sugar brk cup w...
# 54a42cde19925f464b3809d2    large fresh jalapeño inch slice inch thick brk...
# 54a433036529d92b2c015de3    cup chop red onion large brk tablespoon sunflo...
# 54a451926529d92b2c01eda8    pound chicken part brk stalk celery include le...
# 54a430876529d92b2c013e2b    tablespoon olive oil brk cup chop onion brk cu...
# 54a453df6529d92b2c020687    cup granulate sugar brk cup purpose flour brk ...
# 54a41ed76529d92b2c007440     cup fresh lime juice brk cup sugar brk cup water
# 54a42c906529d92b2c010b74    tablespoon stick tablespoon unsalt butter brk ...
# 569519a6dc18ea6c22c9b9ab            cup Japanese short grain white haiga rice
# 54a438d56529d92b2c019648    cup red wine vinegar brk tablespoon mince shal...
# Name: ingredients, dtype: object

# %%
def test_ngrams_maker(min_ngram_length, max_ngram_length):
    def ngrams_per_line(row):
        for ln in row.split(" brk "):
            at_least_two_english_characters_whole_words = r"(?u)\b\w{2,}\b"
            terms = re.findall(at_least_two_english_characters_whole_words, ln)
            for ngramLength in range(min_ngram_length, max_ngram_length):

                # find and return all ngrams
                # for ngram in zip(*[terms[i:] for i in range(3)]):
                # <-- solution without a generator (works the same but has higher memory usage)
                for ngram in (word for i in range(len(terms) - ngramLength + 1) for word in (" ".join(terms[i:i+ngramLength]),)):
                    yield ngram
    return ngrams_per_line

# %%
ngramfied = lemmafied.apply(lambda x: test_ngrams_maker(x, 1, 4))

# %%
ngramfied
# Out:
# id
# 54a4270b19925f464b37c1dc    <generator object test_ngrams_maker at 0x7f2d1...
# 54a42cde19925f464b3809d2    <generator object test_ngrams_maker at 0x7f2d1...
# 54a433036529d92b2c015de3    <generator object test_ngrams_maker at 0x7f2d1...
# 54a451926529d92b2c01eda8    <generator object test_ngrams_maker at 0x7f2d1...
# 54a430876529d92b2c013e2b    <generator object test_ngrams_maker at 0x7f2d1...
# 54a453df6529d92b2c020687    <generator object test_ngrams_maker at 0x7f2d1...
# 55b0e7116284773353bf4580    <generator object test_ngrams_maker at 0x7f2d1...
# 54a42bab6529d92b2c00ffa7    <generator object test_ngrams_maker at 0x7f2d1...
# 54a4748f19925f464b399ef2    <generator object test_ngrams_maker at 0x7f2d1...
# 54a4356a19925f464b3875bb    <generator object test_ngrams_maker at 0x7f2d1...
# 54a4697e6529d92b2c0279d3    <generator object test_ngrams_maker at 0x7f2d1...
# 54a45e426529d92b2c02488f    <generator object test_ngrams_maker at 0x7f2d1...
# 54a452c96529d92b2c01f889    <generator object test_ngrams_maker at 0x7f2d1...
# 54a4323619925f464b384bcc    <generator object test_ngrams_maker at 0x7f2d1...
# 54a4259119925f464b37af9c    <generator object test_ngrams_maker at 0x7f2d1...
# 54a431da6529d92b2c014ee9    <generator object test_ngrams_maker at 0x7f2d1...
# 54a426fd19925f464b37c125    <generator object test_ngrams_maker at 0x7f2d1...
# 54a47bb019925f464b39b9b7    <generator object test_ngrams_maker at 0x7f2d1...
# 54a434d819925f464b386e62    <generator object test_ngrams_maker at 0x7f2d1...
# 54a428116529d92b2c00d1a7    <generator object test_ngrams_maker at 0x7f2d1...
# 54a436036529d92b2c01859e    <generator object test_ngrams_maker at 0x7f2d1...
# 54a47edf19925f464b39c58d    <generator object test_ngrams_maker at 0x7f2d1...
# 54a419706529d92b2c006650    <generator object test_ngrams_maker at 0x7f2d1...
# 54a4349619925f464b386b12    <generator object test_ngrams_maker at 0x7f2d1...
# 54a4340f6529d92b2c016be8    <generator object test_ngrams_maker at 0x7f2d1...
# 54a40e546529d92b2c004606    <generator object test_ngrams_maker at 0x7f2d1...
# 54a428b419925f464b37d5ce    <generator object test_ngrams_maker at 0x7f2d1...
# 54a453a519925f464b38fd16    <generator object test_ngrams_maker at 0x7f2d1...
# 54a41cb219925f464b376d82    <generator object test_ngrams_maker at 0x7f2d1...
# 54a431896529d92b2c014b27    <generator object test_ngrams_maker at 0x7f2d1...
# 54a423ab19925f464b3799f2    <generator object test_ngrams_maker at 0x7f2d1...
# 54a47c1419925f464b39bb28    <generator object test_ngrams_maker at 0x7f2d1...
# 593ee3ba12c27b182380821f    <generator object test_ngrams_maker at 0x7f2d1...
# 54a456366529d92b2c02235a    <generator object test_ngrams_maker at 0x7f2d1...
# 54a452d419925f464b38f1b5    <generator object test_ngrams_maker at 0x7f2d1...
# 54a4659b6529d92b2c026a53    <generator object test_ngrams_maker at 0x7f2d1...
# 54a46d5d19925f464b3982d3    <generator object test_ngrams_maker at 0x7f2d1...
# 54a4582119925f464b3927a1    <generator object test_ngrams_maker at 0x7f2d1...
# 54a4205319925f464b377c9f    <generator object test_ngrams_maker at 0x7f2d1...
# 54a470cc19925f464b39906b    <generator object test_ngrams_maker at 0x7f2d1...
# 54a44f4a6529d92b2c01de45    <generator object test_ngrams_maker at 0x7f2d1...
# 592ef494ae10ad089795ebfa    <generator object test_ngrams_maker at 0x7f2d1...
# 54a41f016529d92b2c00757d    <generator object test_ngrams_maker at 0x7f2d1...
# 54a436266529d92b2c01876e    <generator object test_ngrams_maker at 0x7f2d1...
# 54a428bd19925f464b37d63e    <generator object test_ngrams_maker at 0x7f2d1...
# 54a45a4f6529d92b2c0234d1    <generator object test_ngrams_maker at 0x7f2d1...
# 54a41ed76529d92b2c007440    <generator object test_ngrams_maker at 0x7f2d1...
# 54a42c906529d92b2c010b74    <generator object test_ngrams_maker at 0x7f2d1...
# 569519a6dc18ea6c22c9b9ab    <generator object test_ngrams_maker at 0x7f2d1...
# 54a438d56529d92b2c019648    <generator object test_ngrams_maker at 0x7f2d1...
# Name: ingredients, dtype: object

# %%
lemmafied[0]
# Out:
# 'cup white wine vinegar brk cup sugar brk cup water brk turkish bay leave brk teaspoon dry crush red pepper brk coarse kosher salt brk pound red onion slice brk cup white wine vinegar brk teaspoon dijon mustard brk cup olive oil brk cup crumble blue cheese brk heart romaine quarter lengthwise crumble blue cheese garnish'

# %%
print([ln for ln in lemmafied[0].split(" brk ")])
# Out:
# ['cup white wine vinegar', 'cup sugar', 'cup water', 'turkish bay leave', 'teaspoon dry crush red pepper', 'coarse kosher salt', 'pound red onion slice', 'cup white wine vinegar', 'teaspoon dijon mustard', 'cup olive oil', 'cup crumble blue cheese', 'heart romaine quarter lengthwise crumble blue cheese garnish']

# %%
for ln in lemmafied[0].split(" brk "):
    # tokenize the input string (customize the regex as desired)
    # at_least_two_english_characters_whole_words = u"(?u)\b[a-zA-Z]{2,}\b"
    at_least_two_english_characters_whole_words = r"(?u)\b\w{2,}\b"
    # at_least_two_english_characters_whole_words = u'(?u)\\b\\w+\\b'

    terms = re.findall(at_least_two_english_characters_whole_words, ln)
    print("terms")
    print(terms)
    print("\n")
    for ngramLength in range(1, 5):

        # find and return all ngrams
        # for ngram in zip(*[terms[i:] for i in range(3)]):
        # <-- solution without a generator (works the same but has higher memory usage)
        print('ngrams')
        for ngram in zip(
            *[
                islice(seq, i, len(terms))
                for i, seq in enumerate(tee(terms, ngramLength))
            ]
        ):  # <-- solution using a generator

            ngram = " ".join(ngram)
            print(ngram)
        print("\n")
# Out:
# terms
# ['cup', 'white', 'wine', 'vinegar']
#
#
# ngrams
# cup
# white
# wine
# vinegar
#
#
# ngrams
# cup white
# white wine
# wine vinegar
#
#
# ngrams
# cup white wine
# white wine vinegar
#
#
# ngrams
# cup white wine vinegar
#
#
# terms
# ['cup', 'sugar']
#
#
# ngrams
# cup
# sugar
#
#
# ngrams
# cup sugar
#
#
# ngrams
#
#
# ngrams
#
#
# terms
# ['cup', 'water']
#
#
# ngrams
# cup
# water
#
#
# ngrams
# cup water
#
#
# ngrams
#
#
# ngrams
#
#
# terms
# ['turkish', 'bay', 'leave']
#
#
# ngrams
# turkish
# bay
# leave
#
#
# ngrams
# turkish bay
# bay leave
#
#
# ngrams
# turkish bay leave
#
#
# ngrams
#
#
# terms
# ['teaspoon', 'dry', 'crush', 'red', 'pepper']
#
#
# ngrams
# teaspoon
# dry
# crush
# red
# pepper
#
#
# ngrams
# teaspoon dry
# dry crush
# crush red
# red pepper
#
#
# ngrams
# teaspoon dry crush
# dry crush red
# crush red pepper
#
#
# ngrams
# teaspoon dry crush red
# dry crush red pepper
#
#
# terms
# ['coarse', 'kosher', 'salt']
#
#
# ngrams
# coarse
# kosher
# salt
#
#
# ngrams
# coarse kosher
# kosher salt
#
#
# ngrams
# coarse kosher salt
#
#
# ngrams
#
#
# terms
# ['pound', 'red', 'onion', 'slice']
#
#
# ngrams
# pound
# red
# onion
# slice
#
#
# ngrams
# pound red
# red onion
# onion slice
#
#
# ngrams
# pound red onion
# red onion slice
#
#
# ngrams
# pound red onion slice
#
#
# terms
# ['cup', 'white', 'wine', 'vinegar']
#
#
# ngrams
# cup
# white
# wine
# vinegar
#
#
# ngrams
# cup white
# white wine
# wine vinegar
#
#
# ngrams
# cup white wine
# white wine vinegar
#
#
# ngrams
# cup white wine vinegar
#
#
# terms
# ['teaspoon', 'dijon', 'mustard']
#
#
# ngrams
# teaspoon
# dijon
# mustard
#
#
# ngrams
# teaspoon dijon
# dijon mustard
#
#
# ngrams
# teaspoon dijon mustard
#
#
# ngrams
#
#
# terms
# ['cup', 'olive', 'oil']
#
#
# ngrams
# cup
# olive
# oil
#
#
# ngrams
# cup olive
# olive oil
#
#
# ngrams
# cup olive oil
#
#
# ngrams
#
#
# terms
# ['cup', 'crumble', 'blue', 'cheese']
#
#
# ngrams
# cup
# crumble
# blue
# cheese
#
#
# ngrams
# cup crumble
# crumble blue
# blue cheese
#
#
# ngrams
# cup crumble blue
# crumble blue cheese
#
#
# ngrams
# cup crumble blue cheese
#
#
# terms
# ['heart', 'romaine', 'quarter', 'lengthwise', 'crumble', 'blue', 'cheese', 'garnish']
#
#
# ngrams
# heart
# romaine
# quarter
# lengthwise
# crumble
# blue
# cheese
# garnish
#
#
# ngrams
# heart romaine
# romaine quarter
# quarter lengthwise
# lengthwise crumble
# crumble blue
# blue cheese
# cheese garnish
#
#
# ngrams
# heart romaine quarter
# romaine quarter lengthwise
# quarter lengthwise crumble
# lengthwise crumble blue
# crumble blue cheese
# blue cheese garnish
#
#
# ngrams
# heart romaine quarter lengthwise
# romaine quarter lengthwise crumble
# quarter lengthwise crumble blue
# lengthwise crumble blue cheese
# crumble blue cheese garnish

# %%
test_ngrams_maker(lemmafied[0], 1, 4)
# Out:
# <generator object test_ngrams_maker>

# %%
list(test_ngrams_maker(lemmafied[0], 1, 4))
# Out:
# ['',
#  ' ',
#  ' a ',
#  ' ',
#  ' ',
#  ' n-',
#  ' ',
#  '.',
#  '  ',
#  '   a ',
#  ' a   ',
#  '   ',
#  '   n-',
#  ' n-  ',
#  '  .',
#  '    a ',
#  '   a   ',
#  ' a     ',
#  '     n-',
#  '   n-  ',
#  ' n-   .',
#  '    a   ',
#  '   a     ',
#  ' a       n-',
#  '     n-  ',
#  '   n-   .']

# %%
" ".join(str(word.lemma) 
         for sent in nlp(test_transforms).sentences 
         for word in sent.words 
         if (word.upos not in ["NUM", "DET", "ADV", "CCONJ", "ADP", "SCONJ"]
                            and word is not None
                            ))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[50], line 2
#       1 " ".join(str(word.lemma)
# ----> 2          for sent in nlp(test_transforms).sentences
#       3          for word in sent.words
#       4          if (word.upos not in ["NUM", "DET", "ADV", "CCONJ", "ADP", "SCONJ"]
#       5                             and word is not None
#       6                             ))
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/stanza/pipeline/core.py:471, in Pipeline.__call__(self, doc, processors)
#     470 def __call__(self, doc, processors=None):
# --> 471     return self.process(doc, processors)
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/stanza/pipeline/core.py:394, in Pipeline.process(self, doc, processors)
#     382 def process(self, doc, processors=None):
#     383     """
#     384     Run the pipeline
#     385
#    (...)
#     392         will fail in some unusual manner or just have really bad results
#     393     """
# --> 394     assert any([isinstance(doc, str), isinstance(doc, list),
#     395                 isinstance(doc, Document)]), 'input should be either str, list or Document'
#     397     # empty bulk process
#     398     if isinstance(doc, list) and len(doc) == 0:
#
# AssertionError: input should be either str, list or Document

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {    
    'analyzer': test_ngrams_maker(
        min_ngram_length=1,
        max_ngram_length=4
        ),
    'min_df':3,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

model_input = to_nlp_df['ingredients']

# Do fit transform on data
print("fit_transform start: " + str(datetime.now()))
response = sklearn_transformer.fit_transform(tqdm(model_input)) 
print("fit_transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)
print(transformed_recipe)
print(transformed_recipe.columns)
# Out:
# fit_transform start: 2024-03-14 23:24:12.764496
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[108], line 17
#      15 # Do fit transform on data
#      16 print("fit_transform start: " + str(datetime.now()))
# ---> 17 response = sklearn_transformer.fit_transform(tqdm(model_input))
#      18 print("fit_transform end: " + str(datetime.now()))
#      20 transformed_recipe = pd.DataFrame(
#      21         response.toarray(),
#      22         columns=sklearn_transformer.get_feature_names_out(),
#      23         index=model_input.index
#      24 )
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:2139, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2132 self._check_params()
#    2133 self._tfidf = TfidfTransformer(
#    2134     norm=self.norm,
#    2135     use_idf=self.use_idf,
#    2136     smooth_idf=self.smooth_idf,
#    2137     sublinear_tf=self.sublinear_tf,
#    2138 )
# -> 2139 X = super().fit_transform(raw_documents)
#    2140 self._tfidf.fit(X)
#    2141 # X is already a transformed view of raw_documents so
#    2142 # we set copy to False
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:1389, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1381             warnings.warn(
#    1382                 "Upper case characters found in"
#    1383                 " vocabulary while 'lowercase'"
#    1384                 " is True. These entries will not"
#    1385                 " be matched with any documents"
#    1386             )
#    1387             break
# -> 1389 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1391 if self.binary:
#    1392     X.data.fill(1)
#
# File ~/Repos/Projects/MeaLeon/.venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:1276, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1274 for doc in raw_documents:
#    1275     feature_counter = {}
# -> 1276     for feature in analyze(doc):
#    1277         try:
#    1278             feature_idx = vocabulary[feature]
#
# Cell In[107], line 3, in test_ngrams_maker.<locals>.ngrams_per_line(row)
#       2 def ngrams_per_line(row):
# ----> 3     for ln in row.split(" brk "):
#       4         at_least_two_english_characters_whole_words = r"(?u)\b\w{2,}\b"
#       5         terms = re.findall(at_least_two_english_characters_whole_words, ln)
#
# AttributeError: 'list' object has no attribute 'split'

# %%
nlp2 = stanza.Pipeline('en', 
                    depparse_batch_size=50, 
                    depparse_min_length_to_batch_separately=50,
                    verbose=True,
                    use_gpu=True, # set to true when on cloud/not on streaming computer
                    batch_size=100
                    )
# Out:
# 2024-03-14 21:49:34 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.6.0.json:   0%|   …
# 2024-03-14 21:49:35 INFO: Loading these models for language: en (English):
# ======================================
# | Processor    | Package             |
# --------------------------------------
# | tokenize     | combined            |
# | pos          | combined_charlm     |
# | lemma        | combined_nocharlm   |
# | constituency | ptb3-revised_charlm |
# | depparse     | combined_charlm     |
# | sentiment    | sstplus             |
# | ner          | ontonotes_charlm    |
# ======================================
#
# 2024-03-14 21:49:35 INFO: Using device: cuda
# 2024-03-14 21:49:35 INFO: Loading: tokenize
# 2024-03-14 21:49:38 INFO: Loading: pos
# 2024-03-14 21:49:38 INFO: Loading: lemma
# 2024-03-14 21:49:38 INFO: Loading: constituency
# 2024-03-14 21:49:39 INFO: Loading: depparse
# 2024-03-14 21:49:39 INFO: Loading: sentiment
# 2024-03-14 21:49:39 INFO: Loading: ner
# 2024-03-14 21:49:40 INFO: Done loading processors!

# %%
# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {    
    'analyzer': stanza_analyzer(
        stanza_pipeline=nlp2,
        minNgramLength=1,
        maxNgramLength=4
        ),
    'min_df':3,
    'binary':False
}

sklearn_transformer = TfidfVectorizer(**sklearn_transformer_params)

model_input = to_nlp_df['ingredients']

# Do fit transform on data
print("fit_transform start: " + str(datetime.now()))
response = sklearn_transformer.fit_transform(tqdm(model_input)) 
print("fit_transform end: " + str(datetime.now()))

transformed_recipe = pd.DataFrame(
        response.toarray(),
        columns=sklearn_transformer.get_feature_names_out(),
        index=model_input.index
)
print(transformed_recipe)
print(transformed_recipe.columns)
# Out:
# fit_transform start: 2024-03-14 21:49:43.334964
# 100%|██████████| 50/50 [00:24<00:00,  2.07it/s]
# fit_transform end: 2024-03-14 21:50:07.457198
#                           cup chop onion  cup olive oil  cup sour cream  \
# id
# 54a40e546529d92b2c004606                  0.000000
# 54a428b419925f464b37d5ce                  0.779155
# 54a453a519925f464b38fd16                  0.000000
# 54a41cb219925f464b376d82                  0.000000
# 54a431896529d92b2c014b27                  0.000000
# 54a423ab19925f464b3799f2                  0.000000
# 54a47c1419925f464b39bb28                  0.000000
# 593ee3ba12c27b182380821f                  0.000000
# 54a456366529d92b2c02235a                  0.000000
# 54a452d419925f464b38f1b5                  0.000000
# 54a4659b6529d92b2c026a53                  0.000000
# 54a46d5d19925f464b3982d3                  0.000000
# 54a4582119925f464b3927a1                  0.000000
# 54a4205319925f464b377c9f                  0.000000
# 54a470cc19925f464b39906b                  0.000000
# 54a44f4a6529d92b2c01de45                  0.000000
# 592ef494ae10ad089795ebfa                  0.000000
# 54a41f016529d92b2c00757d                  0.000000
# 54a436266529d92b2c01876e                  0.000000
# 54a428bd19925f464b37d63e                  0.000000
# 54a45a4f6529d92b2c0234d1                  0.000000
# 54a41ed76529d92b2c007440                  0.000000
# 54a42c906529d92b2c010b74                  0.707107
# 569519a6dc18ea6c22c9b9ab                  0.000000
# 54a438d56529d92b2c019648                  0.000000
# Index(['cup chop onion', 'cup olive oil', 'cup sour cream', 'cup sugar',
#        'cup water', 'large egg', 'tablespoon extra-virgin olive oil',
#        'tablespoon fresh lemon juice', 'tablespoon olive oil',
#        'tablespoon sugar', 'tablespoon white wine vinegar',
#        'teaspoon ground cumin', 'teaspoon salt', 'teaspoon vanilla extract'],
#       dtype='object')

# %%
# load from MLflow
mlflow_client = mlflow.tracking.MlflowClient(
    tracking_uri=f'https://dagshub.com/{DAGSHUB_USER_NAME}/MeaLeon.mlflow')

# cv_params are parameters for the sklearn CountVectorizer or TFIDFVectorizer
sklearn_transformer_params = {
    # 'strip_accents':"unicode",
    # 'lowercase':True,
    'analyzer': CustomSKLearnAnalyzer().stanza_analyzer(stanza_pipeline=nlp, minNgramLength=1, maxNgramLength=4),
    'min_df':3,
    'binary':True
}

# bertopic_params are a superset of cv_params
# bertopic_params = {
#     'top_n_words':20,
#     'min_topic_size':5,
#     'nr_topics':'auto',
#     'verbose':True,
#     'low_memory':True,
#     'calculate_probabilities':True
# }

# update bertopic_params to include cv_params
# bertopic_params.update(cv_params)

# pipeline_params are parameters that will be logged in MLFlow and are a superset of library parameters
pipeline_params = {
    'stanza_model': 'en',
    'sklearn-transformer': 'OneHotEncoder'
}

# update the pipeline parameters with the library-specific ones so that they show up in MLflow Tracking
pipeline_params.update(sklearn_transformer_params)
# pipeline_params.update(bertopic_params)

# signature = infer_signature(model_input=to_nlp_df['ingredients'],
#                             )

with mlflow.start_run(experiment_id=mlflow_exp_id):    
    # LOG PARAMETERS
    mlflow.log_params(pipeline_params)

    # LOG INPUTS (QUERIES) AND OUTPUTS
    # MLflow example uses a list of strings or a list of str->str dicts
    # Will be useful in STAGING/Evaluation
    
    # LOG MODEL
    # Instantiate sklearn OneHotEncoder
    sklearn_transformer = CountVectorizer(**sklearn_transformer_params)

    print('\n')
    print('-' * 80)
    print('sklearn fit transform on ingredients:', end='\n')

    model_input = to_nlp_df['ingredients']

    print('\n')
    print('-' * 80)
    print('Input Data: ', end='\n')
    print(model_input)

    print('\n')
    print('-' * 80)
    print('Input Data Shape: ', end='\n')
    print(model_input.shape)

    print('\n')
    print('-' * 80)
    print('Random 3 Records from Input Data: ', end='\n')
    print(model_input.sample(3, random_state=200))

    # Do fit transform on data
    response = sklearn_transformer.fit_transform(tqdm(model_input)) 
    
    transformed_recipe = pd.DataFrame(
            response.toarray(),
            columns=sklearn_transformer.get_feature_names_out(),
            index=model_input.index
    )

    signature = infer_signature(model_input=model_input,
                                model_output=transformed_recipe
                                )

    print('\n')
    print('-' * 80)
    print('Transformed Data:', end='\n')
    print(transformed_recipe)
    
    # mlflow.pyfunc.save_model(
    #     path=model_directory,
    #     code_path=["../src/"],
    #     python_model=CustomSKLearnWrapper(),
    #     input_example=to_nlp_df['ingredients'][0],    
    #     artifacts=artifacts
    # )

     # joblib.dump(sklearn_transformer, sklearn_transformer_path)
    with open(sklearn_transformer_path, "wb") as fo:
        pickle.dump(sklearn_transformer, fo)
        # mlflow.log_artifact(sklearn_transformer_path,
        #                     artifact_path='sklearn_transformer')

    # joblib.dump(transformed_recipe, transformed_recipes_path)
    with open(transformed_recipes_path, "wb") as fo:
        pickle.dump(transformed_recipe, fo)
        # mlflow.log_artifact(transformed_recipes_path,
        #                     artifact_path='transformed_recipes')


    model_info = mlflow.pyfunc.log_model( 
        code_path=["../src/"],
        python_model=CustomSKLearnWrapper(),
        input_example=to_nlp_df['ingredients'][0],
        signature=signature,        
        artifact_path="sklearn_model",
        artifacts=artifacts
        ) 

    # since this uses a custom Stanza analyzer, we have to use a custom mlflow.Pyfunc.PythonModel

# %%
response

# %%
test_predictor = mlflow.pyfunc.load_model(model_uri=model_info.model_uri)

# %%
# pre_proc_df is cleaned dataframe
pre_proc_test_df = dfpp.preprocess_dataframe(test_df)
print('\n')
print('--------------')
print('Preprocessed Dataframe: ', end='\n')
print(pre_proc_test_df.head())
print(pre_proc_test_df.shape)

# create subset for dev purposes
# to_nlp_test_df = pre_proc_test_df
# print('\n')
# print('-' * 80)
# print('Subset Dataframe:', end='\n')
# print(to_nlp_test_df.head())
# print(to_nlp_test_df.shape)

test_model_input = pre_proc_test_df['ingredients']

# %%
test_model_input

# %%
test_model_input.shape

# %%
test_model_input.values

# %%
model_info.signature.to_dict()

# %%
test_predictor.predict(test_model_input)

# %%
print('\n')
print('-' * 80)
print('Input Data: ', end='\n')
print(test_model_input)

print('\n')
print('-' * 80)
print('Input Data Shape: ', end='\n')
print(test_model_input.shape)

print('\n')
print('-' * 80)
print('Random 3 Records from Input Data: ', end='\n')
print(test_model_input.sample(3, random_state=200))

# test_response = sklearn_transformer.transform(tqdm(test_model_input)) 
test_response = sklearn_transformer.transform(test_model_input)
    
    
test_transformed_recipe = pd.DataFrame(
            test_response.toarray(),
            columns=sklearn_transformer.get_feature_names_out(),
            index=test_model_input.index
    )

# %%
type(test_predictor)

# %%
test_transformed_recipe

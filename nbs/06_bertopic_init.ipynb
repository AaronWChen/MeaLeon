# %% [markdown]
# # core
#
# > test

# %% [markdown]
# # | default_exp core

# %%
# | hide
from nbdev.showdoc import *

from bertopic import BERTopic
from datetime import datetime
from joblib import load
import matplotlib.pyplot as plt
import mlflow
from mlflow.models.signature import infer_signature

# import numpy as np
import pandas as pd
from sklearn.base import TransformerMixin
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import (
    CountVectorizer,
    TfidfTransformer,
    TfidfVectorizer,
)
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# import spacy
# import en_core_web_sm
# from spacy.lang.en.stop_words import STOP_WORDS

# from spacy.lemmatizer import Lemmatizer
from tqdm import tqdm
from typing import Any
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/lib/python3.10/site-packages/torch/__init__.py:168, in _load_global_deps()
#     167 try:
# --> 168     ctypes.CDLL(lib_path, mode=ctypes.RTLD_GLOBAL)
#     169 except OSError as err:
#     170     # Can only happen for wheel with cuda libs as PYPI deps
#     171     # As PyTorch is not purelib, but nvidia-*-cu11 is
#
# File ~/.asdf/installs/python/3.10.10/lib/python3.10/ctypes/__init__.py:374, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     373 if handle is None:
# --> 374     self._handle = _dlopen(self._name, mode)
#     375 else:
#
# OSError: libcufft.so.10: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 # | hide
#       2 from nbdev.showdoc import *
# ----> 4 from bertopic import BERTopic
#       5 from datetime import datetime
#       6 from joblib import  load
#
# File ~/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/lib/python3.10/site-packages/bertopic/__init__.py:1
# ----> 1 from bertopic._bertopic import BERTopic
#       3 __version__ = "0.15.0"
#       5 __all__ = [
#       6     "BERTopic",
#       7 ]
#
# File ~/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/lib/python3.10/site-packages/bertopic/_bertopic.py:48
#      46 from bertopic import plotting
#      47 from bertopic.cluster import BaseCluster
# ---> 48 from bertopic.backend import BaseEmbedder
#      49 from bertopic.representation._mmr import mmr
#      50 from bertopic.backend._utils import select_backend
#
# File ~/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/lib/python3.10/site-packages/bertopic/backend/__init__.py:22
#      20 # Multimodal Embeddings
#      21 try:
# ---> 22     from bertopic.backend._multimodal import MultiModalBackend
#      23 except ModuleNotFoundError:
#      24     msg = "`pip install bertopic[vision]` \n\n"
#
# File ~/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/lib/python3.10/site-packages/bertopic/backend/_multimodal.py:6
#       4 from tqdm import tqdm
#       5 from typing import List, Union
# ----> 6 from sentence_transformers import SentenceTransformer
#       8 from bertopic.backend import BaseEmbedder
#      11 class MultiModalBackend(BaseEmbedder):
#
# File ~/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/lib/python3.10/site-packages/sentence_transformers/__init__.py:3
#       1 __version__ = "2.2.2"
#       2 __MODEL_HUB_ORGANIZATION__ = 'sentence-transformers'
# ----> 3 from .datasets import SentencesDataset, ParallelSentencesDataset
#       4 from .LoggingHandler import LoggingHandler
#       5 from .SentenceTransformer import SentenceTransformer
#
# File ~/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/lib/python3.10/site-packages/sentence_transformers/datasets/__init__.py:1
# ----> 1 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#       2 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
#       3 from .ParallelSentencesDataset import ParallelSentencesDataset
#
# File ~/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/lib/python3.10/site-packages/sentence_transformers/datasets/DenoisingAutoEncoderDataset.py:1
# ----> 1 from torch.utils.data import Dataset
#       2 from typing import List
#       3 from ..readers.InputExample import InputExample
#
# File ~/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/lib/python3.10/site-packages/torch/__init__.py:228
#     217 else:
#     218     # Easy way.  You want this most of the time, because it will prevent
#     219     # C++ symbols from libtorch clobbering C++ symbols from other
#    (...)
#     225     #
#     226     # See Note [Global dependencies]
#     227     if USE_GLOBAL_DEPS:
# --> 228         _load_global_deps()
#     229     from torch._C import *  # noqa: F403
#     231 # Appease the type checker; ordinarily this binding is inserted by the
#     232 # torch._C module initialization code in C
#
# File ~/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/lib/python3.10/site-packages/torch/__init__.py:189, in _load_global_deps()
#     187     raise err
#     188 for lib_folder, lib_name in cuda_libs.items():
# --> 189     _preload_cuda_deps(lib_folder, lib_name)
#     190 ctypes.CDLL(lib_path, mode=ctypes.RTLD_GLOBAL)
#
# File ~/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/lib/python3.10/site-packages/torch/__init__.py:154, in _preload_cuda_deps(lib_folder, lib_name)
#     152         break
#     153 if not lib_path:
# --> 154     raise ValueError(f"{lib_name} not found in the system path {sys.path}")
#     155 ctypes.CDLL(lib_path)
#
# ValueError: libcublas.so.*[0-9] not found in the system path ['/home/awchen/Repos/Projects/MeaLeon/nbs', '/home/awchen/.asdf/installs/python/3.10.10/lib/python310.zip', '/home/awchen/.asdf/installs/python/3.10.10/lib/python3.10', '/home/awchen/.asdf/installs/python/3.10.10/lib/python3.10/lib-dynload', '', '/home/awchen/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/lib/python3.10/site-packages', '/home/awchen/Repos/Projects/MeaLeon']

# %%
# !echo $PATH
# Out:
# /home/awchen/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/bin:/home/awchen/.vscode-server/bin/660393deaaa6d1996740ff4880f1bad43768c814/bin/remote-cli:/home/awchen/.local/bin:/home/awchen/.local/bin:/home/awchen/.cache/pypoetry/virtualenvs/mealeon-uA1PI5_p-py3.10/bin:/home/awchen/.local/bin:/home/awchen/.local/bin:/home/awchen/.asdf/shims:/home/awchen/.asdf/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/usr/lib/wsl/lib:/mnt/c/Windows/system32:/mnt/c/Windows:/mnt/c/Windows/System32/Wbem:/mnt/c/Windows/System32/WindowsPowerShell/v1.0/:/mnt/c/Windows/System32/OpenSSH/:/mnt/c/Program Files/dotnet/:/mnt/c/WINDOWS/system32:/mnt/c/WINDOWS:/mnt/c/WINDOWS/System32/Wbem:/mnt/c/WINDOWS/System32/WindowsPowerShell/v1.0/:/mnt/c/WINDOWS/System32/OpenSSH/:/mnt/c/Program Files/NVIDIA Corporation/NVIDIA NvDLISR:/mnt/c/Users/aaron/AppData/Local/Microsoft/WindowsApps:/mnt/c/Users/aaron/AppData/Local/Programs/Microsoft VS Code/bin

# %%
data_path = "../data/recipes-en-201706/epicurious-recipes_m2.json"

repo = pd.read_json(path_or_buf=data_path)  # type:ignore
pd.read_json(data_path, typ="frame")  # type:ignore

dfpp.preprocess_dataframe(df=repo)  # type:ignore
print(repo.shape)
repo.head(10)  # type:ignore

# %% [markdown]
# # | export
# def foo():
#     pass

# %%
# | hide
import nbdev

nbdev.nbdev_export()

# %% [raw]
# ---
# description: Have a favorite dish but want to try something with similar ingredients
#   but from another cuisine? MeaLeon uses natural language processing to compare the
#   ingredients of a dish you like and finds 5 dishes from Epicurious, along with links
#   to those recipe pages! Dataset here https://www.kaggle.com/datasets/awchen/ogmealeondata
# output-file: index.html
# title: MeaLeon
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install MeaLeon
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
